# %% [markdown]
# # Settings

# %%
# gpu status
# !nvidia-smi

# %%
# install packages
# !pip install -r requirements.txt --user --quiet -U
# !pip uninstall torch -y
# !pip install torch==1.8.0
# !apt updates

# %%
# !sudo apt update
# !sudo apt install libgl1-mesa-glx ffmpeg libsm6 libxext6 -y

# %%
# !sudo rm -r logs

# %%
# log into weight and bias, if error occurs, please reset your jupyter kernal
import wandb
wandb.login()

# %% [markdown]
# # Train

# %%
# run training
# !CUDA_VISIBLE_DEVICES=0 python train.py --project Retina \
                                        --data_dir ../Retina/dataset/DRIVE \
                                        --data_module dataset \
                                        --net waveletunet_r2 \
                                        --net_inputch 3 \
                                        --net_outputch 3 \
                                        --net_norm batch \
                                        --lossfn BoundaryCELoss \
                                        --precision 16 \
                                        --data_patchsize 128_128 \
                                        --batch_size 24
# Out:
# args: Namespace(batch_size=24, data_cropsize=None, data_dir='../Retina/dataset/DRIVE', data_module='dataset', data_padsize=None, data_patchsize='128_128', data_resize=None, experiment_name=None, lossfn='BoundaryCELoss', lr=0, net='waveletunet_r2', net_ckpt=None, net_inputch=3, net_norm='batch', net_outputch=3, precision=16, project='Retina')
#
# project Retina
# Current Experiment: DatasetDRIVE_Netwaveletunet_r2_Netinputch3_Netoutputch3_LossBoundaryCELoss_Lr0_Precision16_Patchsize128_128_PrefixNone_
#  ****************************************************************************************************
# wandb: Currently logged in as: keewonshin (use `wandb login --relogin` to force relogin)
# /opt/conda/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# /opt/conda/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run DatasetDRIVE_Netwaveletunet_r2_Netinputch3_Netoutputch3_LossBoundaryCELoss_Lr0_Precision16_Patchsize128_128_PrefixNone_
# wandb:  View project at https://wandb.ai/keewonshin/Retina
# wandb:  View run at https://wandb.ai/keewonshin/Retina/runs/2pxaejl1
# wandb: Run data is saved locally in logs/wandb/run-20210805_143318-2pxaejl1
# wandb: Run `wandb offline` to turn off syncing.
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# total counts of dataset x 18, y 18
# total counts of dataset x 2, y 2
# total counts of dataset x 20, y 20
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name   | Type           | Params
# ------------------------------------------
# 0 | lossfn | BoundaryCELoss | 0
# 1 | net    | waveletunet_r2 | 55.7 M
# 2 | metric | F1             | 0
# ------------------------------------------
# 55.7 M    Trainable params
# 0         Non-trainable params
# 55.7 M    Total params
# 222.716   Total estimated model params size (MB)
# Epoch 0:  50%|▌| 1/2 [00:06<00:06,  6.08s/it, loss=1.79, v_num=ejl1, loss_val=1./home/kevin/.local/lib/python3.8/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
#
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█| 2/2 [00:22<00:00, 11.34s/it, loss=1.790, v_num=ejl1, loss_val=1
#                                                                                 Epoch 0, global step 0: loss_val reached 1.91802 (best 1.91802), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0000-loss_val=1.9180-metric_val=0.4603.ckpt" as top 3
# Epoch 1:  50%|▌| 1/2 [00:08<00:08,  8.22s/it, loss=1.790, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 2/2 [00:24<00:00, 12.31s/it, loss=1.800, v_num=ejl1, loss_val=1
#                                                                                 Epoch 1, global step 1: loss_val reached 1.91977 (best 1.91802), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0001-loss_val=1.9198-metric_val=0.4743.ckpt" as top 3
# Epoch 2:  50%|▌| 1/2 [00:06<00:06,  6.22s/it, loss=1.800, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 2/2 [00:23<00:00, 11.99s/it, loss=1.800, v_num=ejl1, loss_val=1
#                                                                                 Epoch 2, global step 2: loss_val reached 1.92150 (best 1.91802), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0002-loss_val=1.9215-metric_val=0.4859.ckpt" as top 3
# Epoch 3:  50%|▌| 1/2 [00:07<00:07,  7.93s/it, loss=1.800, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 2/2 [00:26<00:00, 13.12s/it, loss=1.840, v_num=ejl1, loss_val=1
#                                                                                 Epoch 3, global step 3: loss_val was not in top 3
# Epoch 4:  50%|▌| 1/2 [00:05<00:05,  5.12s/it, loss=1.840, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 2/2 [00:22<00:00, 11.13s/it, loss=1.800, v_num=ejl1, loss_val=1
#                                                                                 Epoch 4, global step 4: loss_val reached 1.91910 (best 1.91802), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0004-loss_val=1.9191-metric_val=0.4906.ckpt" as top 3
# Epoch 5:  50%|▌| 1/2 [00:08<00:08,  8.89s/it, loss=1.800, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 2/2 [00:25<00:00, 12.90s/it, loss=1.820, v_num=ejl1, loss_val=1
#                                                                                 Epoch 5, global step 5: loss_val reached 1.91529 (best 1.91529), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0005-loss_val=1.9153-metric_val=0.4972.ckpt" as top 3
# Epoch 6:  50%|▌| 1/2 [00:05<00:05,  5.35s/it, loss=1.820, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 2/2 [00:20<00:00, 10.47s/it, loss=1.800, v_num=ejl1, loss_val=1
#                                                                                 Epoch 6, global step 6: loss_val reached 1.91190 (best 1.91190), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0006-loss_val=1.9119-metric_val=0.5043.ckpt" as top 3
# Epoch 7:  50%|▌| 1/2 [00:07<00:07,  7.15s/it, loss=1.800, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 2/2 [00:24<00:00, 12.21s/it, loss=1.780, v_num=ejl1, loss_val=1
#                                                                                 Epoch 7, global step 7: loss_val reached 1.90845 (best 1.90845), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0007-loss_val=1.9084-metric_val=0.5141.ckpt" as top 3
# Epoch 8:  50%|▌| 1/2 [00:05<00:05,  5.38s/it, loss=1.780, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 2/2 [00:21<00:00, 10.88s/it, loss=1.780, v_num=ejl1, loss_val=1
#                                                                                 Epoch 8, global step 8: loss_val reached 1.90472 (best 1.90472), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0008-loss_val=1.9047-metric_val=0.5260.ckpt" as top 3
# Epoch 9:  50%|▌| 1/2 [00:09<00:09,  9.53s/it, loss=1.780, v_num=ejl1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 2/2 [00:25<00:00, 12.58s/it, loss=1.790, v_num=ejl1, loss_val=1
#                                                                                 Epoch 9, global step 9: loss_val reached 1.90130 (best 1.90130), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0009-loss_val=1.9013-metric_val=0.5345.ckpt" as top 3
# Epoch 10:  50%|▌| 1/2 [00:07<00:07,  7.13s/it, loss=1.790, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 2/2 [00:23<00:00, 11.72s/it, loss=1.780, v_num=ejl1, loss_val=
#                                                                                 Epoch 10, global step 10: loss_val reached 1.89699 (best 1.89699), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0010-loss_val=1.8970-metric_val=0.5434.ckpt" as top 3
# Epoch 11:  50%|▌| 1/2 [00:09<00:09,  9.03s/it, loss=1.780, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 2/2 [00:24<00:00, 12.33s/it, loss=1.750, v_num=ejl1, loss_val=
#                                                                                 Epoch 11, global step 11: loss_val reached 1.89146 (best 1.89146), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0011-loss_val=1.8915-metric_val=0.5512.ckpt" as top 3
# Epoch 12:  50%|▌| 1/2 [00:05<00:05,  5.93s/it, loss=1.750, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 2/2 [00:21<00:00, 10.52s/it, loss=1.770, v_num=ejl1, loss_val=
#                                                                                 Epoch 12, global step 12: loss_val reached 1.88640 (best 1.88640), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0012-loss_val=1.8864-metric_val=0.5539.ckpt" as top 3
# Epoch 13:  50%|▌| 1/2 [00:07<00:07,  7.39s/it, loss=1.770, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 2/2 [00:23<00:00, 11.76s/it, loss=1.760, v_num=ejl1, loss_val=
#                                                                                 Epoch 13, global step 13: loss_val reached 1.87933 (best 1.87933), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0013-loss_val=1.8793-metric_val=0.5577.ckpt" as top 3
# Epoch 14:  50%|▌| 1/2 [00:08<00:08,  8.51s/it, loss=1.760, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 2/2 [00:24<00:00, 12.26s/it, loss=1.760, v_num=ejl1, loss_val=
#                                                                                 Epoch 14, global step 14: loss_val reached 1.87226 (best 1.87226), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0014-loss_val=1.8723-metric_val=0.5603.ckpt" as top 3
# Epoch 15:  50%|▌| 1/2 [00:06<00:06,  6.36s/it, loss=1.760, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 2/2 [00:24<00:00, 12.27s/it, loss=1.750, v_num=ejl1, loss_val=
#                                                                                 Epoch 15, global step 15: loss_val reached 1.86690 (best 1.86690), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0015-loss_val=1.8669-metric_val=0.5641.ckpt" as top 3
# Epoch 16:  50%|▌| 1/2 [00:06<00:06,  6.99s/it, loss=1.750, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 2/2 [00:24<00:00, 12.20s/it, loss=1.770, v_num=ejl1, loss_val=
#                                                                                 Epoch 16, global step 16: loss_val reached 1.86102 (best 1.86102), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0016-loss_val=1.8610-metric_val=0.5654.ckpt" as top 3
# Epoch 17:  50%|▌| 1/2 [00:06<00:06,  6.66s/it, loss=1.770, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 2/2 [00:23<00:00, 11.66s/it, loss=1.800, v_num=ejl1, loss_val=
#                                                                                 Epoch 17, global step 17: loss_val reached 1.85752 (best 1.85752), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0017-loss_val=1.8575-metric_val=0.5641.ckpt" as top 3
# Epoch 18:  50%|▌| 1/2 [00:08<00:08,  8.62s/it, loss=1.800, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 2/2 [00:23<00:00, 11.74s/it, loss=1.760, v_num=ejl1, loss_val=
#                                                                                 Epoch 18, global step 18: loss_val reached 1.85460 (best 1.85460), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0018-loss_val=1.8546-metric_val=0.5649.ckpt" as top 3
# Epoch 19:  50%|▌| 1/2 [00:08<00:08,  8.37s/it, loss=1.760, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 2/2 [00:20<00:00, 10.39s/it, loss=1.730, v_num=ejl1, loss_val=
#                                                                                 Epoch 19, global step 19: loss_val reached 1.84996 (best 1.84996), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0019-loss_val=1.8500-metric_val=0.5678.ckpt" as top 3
# Epoch 20:  50%|▌| 1/2 [00:06<00:06,  6.53s/it, loss=1.730, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 2/2 [00:18<00:00,  9.22s/it, loss=1.730, v_num=ejl1, loss_val=
#                                                                                 Epoch 20, global step 20: loss_val reached 1.84593 (best 1.84593), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0020-loss_val=1.8459-metric_val=0.5716.ckpt" as top 3
# Epoch 21:  50%|▌| 1/2 [00:05<00:05,  5.81s/it, loss=1.730, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 2/2 [00:18<00:00,  9.06s/it, loss=1.740, v_num=ejl1, loss_val=
#                                                                                 Epoch 21, global step 21: loss_val reached 1.84141 (best 1.84141), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0021-loss_val=1.8414-metric_val=0.5740.ckpt" as top 3
# Epoch 22:  50%|▌| 1/2 [00:06<00:06,  6.60s/it, loss=1.740, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 2/2 [00:20<00:00, 10.40s/it, loss=1.750, v_num=ejl1, loss_val=
#                                                                                 Epoch 22, global step 22: loss_val reached 1.83817 (best 1.83817), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0022-loss_val=1.8382-metric_val=0.5780.ckpt" as top 3
# Epoch 23:  50%|▌| 1/2 [00:06<00:06,  6.28s/it, loss=1.750, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|█| 2/2 [00:22<00:00, 11.42s/it, loss=1.750, v_num=ejl1, loss_val=
#                                                                                 Epoch 23, global step 23: loss_val reached 1.83383 (best 1.83383), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0023-loss_val=1.8338-metric_val=0.5797.ckpt" as top 3
# Epoch 24:  50%|▌| 1/2 [00:07<00:07,  7.81s/it, loss=1.750, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|█| 2/2 [00:21<00:00, 10.79s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 24, global step 24: loss_val reached 1.83033 (best 1.83033), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0024-loss_val=1.8303-metric_val=0.5840.ckpt" as top 3
# Epoch 25:  50%|▌| 1/2 [00:06<00:06,  6.32s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 25: 100%|█| 2/2 [00:18<00:00,  9.04s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 25, global step 25: loss_val reached 1.82901 (best 1.82901), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0025-loss_val=1.8290-metric_val=0.5844.ckpt" as top 3
# Epoch 26:  50%|▌| 1/2 [00:07<00:07,  7.04s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 26: 100%|█| 2/2 [00:23<00:00, 11.64s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 26, global step 26: loss_val reached 1.82776 (best 1.82776), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0026-loss_val=1.8278-metric_val=0.5851.ckpt" as top 3
# Epoch 27:  50%|▌| 1/2 [00:08<00:08,  8.06s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 27: 100%|█| 2/2 [00:24<00:00, 12.31s/it, loss=1.750, v_num=ejl1, loss_val=
#                                                                                 Epoch 27, global step 27: loss_val reached 1.82338 (best 1.82338), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0027-loss_val=1.8234-metric_val=0.5831.ckpt" as top 3
# Epoch 28:  50%|▌| 1/2 [00:06<00:06,  6.75s/it, loss=1.750, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 28: 100%|█| 2/2 [00:23<00:00, 11.91s/it, loss=1.700, v_num=ejl1, loss_val=
#                                                                                 Epoch 28, global step 28: loss_val reached 1.82188 (best 1.82188), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0028-loss_val=1.8219-metric_val=0.5852.ckpt" as top 3
# Epoch 29:  50%|▌| 1/2 [00:07<00:07,  7.78s/it, loss=1.700, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 29: 100%|█| 2/2 [00:25<00:00, 12.55s/it, loss=1.720, v_num=ejl1, loss_val=
#                                                                                 Epoch 29, global step 29: loss_val reached 1.82079 (best 1.82079), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0029-loss_val=1.8208-metric_val=0.5846.ckpt" as top 3
# Epoch 30:  50%|▌| 1/2 [00:07<00:07,  7.88s/it, loss=1.720, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 30: 100%|█| 2/2 [00:24<00:00, 12.11s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 30, global step 30: loss_val reached 1.82102 (best 1.82079), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0030-loss_val=1.8210-metric_val=0.5851.ckpt" as top 3
# Epoch 31:  50%|▌| 1/2 [00:06<00:06,  6.34s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 31: 100%|█| 2/2 [00:22<00:00, 11.15s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 31, global step 31: loss_val reached 1.82097 (best 1.82079), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0031-loss_val=1.8210-metric_val=0.5834.ckpt" as top 3
# Epoch 32:  50%|▌| 1/2 [00:06<00:06,  6.83s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 32: 100%|█| 2/2 [00:23<00:00, 11.62s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 32, global step 32: loss_val reached 1.82066 (best 1.82066), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0032-loss_val=1.8207-metric_val=0.5834.ckpt" as top 3
# Epoch 33:  50%|▌| 1/2 [00:05<00:05,  5.94s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 33: 100%|█| 2/2 [00:21<00:00, 10.98s/it, loss=1.730, v_num=ejl1, loss_val=
#                                                                                 Epoch 33, global step 33: loss_val reached 1.81893 (best 1.81893), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0033-loss_val=1.8189-metric_val=0.5803.ckpt" as top 3
# Epoch 34:  50%|▌| 1/2 [00:05<00:05,  5.95s/it, loss=1.730, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 34: 100%|█| 2/2 [00:21<00:00, 10.87s/it, loss=1.700, v_num=ejl1, loss_val=
#                                                                                 Epoch 34, global step 34: loss_val reached 1.81987 (best 1.81893), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0034-loss_val=1.8199-metric_val=0.5794.ckpt" as top 3
# Epoch 35:  50%|▌| 1/2 [00:07<00:07,  7.40s/it, loss=1.700, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 35: 100%|█| 2/2 [00:23<00:00, 11.50s/it, loss=1.700, v_num=ejl1, loss_val=
#                                                                                 Epoch 35, global step 35: loss_val reached 1.81870 (best 1.81870), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0035-loss_val=1.8187-metric_val=0.5779.ckpt" as top 3
# Epoch 36:  50%|▌| 1/2 [00:06<00:06,  6.43s/it, loss=1.700, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 36: 100%|█| 2/2 [00:22<00:00, 11.45s/it, loss=1.700, v_num=ejl1, loss_val=
#                                                                                 Epoch 36, global step 36: loss_val reached 1.81723 (best 1.81723), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0036-loss_val=1.8172-metric_val=0.5765.ckpt" as top 3
# Epoch 37:  50%|▌| 1/2 [00:08<00:08,  8.69s/it, loss=1.700, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 37: 100%|█| 2/2 [00:24<00:00, 12.43s/it, loss=1.700, v_num=ejl1, loss_val=
#                                                                                 Epoch 37, global step 37: loss_val reached 1.81333 (best 1.81333), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0037-loss_val=1.8133-metric_val=0.5755.ckpt" as top 3
# Epoch 38:  50%|▌| 1/2 [00:08<00:08,  8.48s/it, loss=1.700, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 38: 100%|█| 2/2 [00:24<00:00, 12.47s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 38, global step 38: loss_val reached 1.81379 (best 1.81333), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0038-loss_val=1.8138-metric_val=0.5776.ckpt" as top 3
# Epoch 39:  50%|▌| 1/2 [00:07<00:07,  7.99s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 39: 100%|█| 2/2 [00:25<00:00, 12.57s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 39, global step 39: loss_val reached 1.81430 (best 1.81333), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0039-loss_val=1.8143-metric_val=0.5779.ckpt" as top 3
# Epoch 40:  50%|▌| 1/2 [00:06<00:06,  6.66s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 40: 100%|█| 2/2 [00:22<00:00, 11.48s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 40, global step 40: loss_val was not in top 3
# Epoch 41:  50%|▌| 1/2 [00:06<00:06,  6.18s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 41: 100%|█| 2/2 [00:21<00:00, 10.99s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 41, global step 41: loss_val reached 1.80932 (best 1.80932), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0041-loss_val=1.8093-metric_val=0.5787.ckpt" as top 3
# Epoch 42:  50%|▌| 1/2 [00:07<00:07,  7.29s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 42: 100%|█| 2/2 [00:24<00:00, 12.07s/it, loss=1.680, v_num=ejl1, loss_val=
#                                                                                 Epoch 42, global step 42: loss_val reached 1.80465 (best 1.80465), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0042-loss_val=1.8047-metric_val=0.5786.ckpt" as top 3
# Epoch 43:  50%|▌| 1/2 [00:07<00:07,  7.85s/it, loss=1.680, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 43: 100%|█| 2/2 [00:24<00:00, 12.42s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 43, global step 43: loss_val reached 1.80300 (best 1.80300), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0043-loss_val=1.8030-metric_val=0.5777.ckpt" as top 3
# Epoch 44:  50%|▌| 1/2 [00:06<00:06,  6.31s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 44: 100%|█| 2/2 [00:24<00:00, 12.08s/it, loss=1.660, v_num=ejl1, loss_val=
#                                                                                 Epoch 44, global step 44: loss_val reached 1.80654 (best 1.80300), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0044-loss_val=1.8065-metric_val=0.5806.ckpt" as top 3
# Epoch 45:  50%|▌| 1/2 [00:08<00:08,  8.98s/it, loss=1.660, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 45: 100%|█| 2/2 [00:26<00:00, 13.25s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 45, global step 45: loss_val reached 1.80410 (best 1.80300), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0045-loss_val=1.8041-metric_val=0.5807.ckpt" as top 3
# Epoch 46:  50%|▌| 1/2 [00:06<00:06,  6.07s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 46: 100%|█| 2/2 [00:23<00:00, 11.74s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 46, global step 46: loss_val was not in top 3
# Epoch 47:  50%|▌| 1/2 [00:06<00:06,  6.37s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 47: 100%|█| 2/2 [00:24<00:00, 12.20s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 47, global step 47: loss_val reached 1.80010 (best 1.80010), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0047-loss_val=1.8001-metric_val=0.5812.ckpt" as top 3
# Epoch 48:  50%|▌| 1/2 [00:06<00:06,  6.41s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 48: 100%|█| 2/2 [00:22<00:00, 11.36s/it, loss=1.660, v_num=ejl1, loss_val=
#                                                                                 Epoch 48, global step 48: loss_val reached 1.79993 (best 1.79993), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0048-loss_val=1.7999-metric_val=0.5834.ckpt" as top 3
# Epoch 49:  50%|▌| 1/2 [00:09<00:09,  9.60s/it, loss=1.660, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█| 2/2 [00:27<00:00, 13.54s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 49, global step 49: loss_val was not in top 3
# Epoch 50:  50%|▌| 1/2 [00:07<00:07,  7.11s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 50: 100%|█| 2/2 [00:24<00:00, 12.14s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 50, global step 50: loss_val reached 1.79622 (best 1.79622), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0050-loss_val=1.7962-metric_val=0.5845.ckpt" as top 3
# Epoch 51:  50%|▌| 1/2 [00:05<00:05,  5.82s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 51: 100%|█| 2/2 [00:23<00:00, 11.90s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 51, global step 51: loss_val reached 1.79145 (best 1.79145), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0051-loss_val=1.7914-metric_val=0.5841.ckpt" as top 3
# Epoch 52:  50%|▌| 1/2 [00:06<00:06,  6.58s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 52: 100%|█| 2/2 [00:24<00:00, 12.32s/it, loss=1.680, v_num=ejl1, loss_val=
#                                                                                 Epoch 52, global step 52: loss_val reached 1.79326 (best 1.79145), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0052-loss_val=1.7933-metric_val=0.5837.ckpt" as top 3
# Epoch 53:  50%|▌| 1/2 [00:09<00:09,  9.23s/it, loss=1.680, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 53: 100%|█| 2/2 [00:27<00:00, 13.74s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 53, global step 53: loss_val reached 1.78818 (best 1.78818), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0053-loss_val=1.7882-metric_val=0.5826.ckpt" as top 3
# Epoch 54:  50%|▌| 1/2 [00:07<00:07,  7.55s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 54: 100%|█| 2/2 [00:23<00:00, 11.79s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 54, global step 54: loss_val reached 1.78744 (best 1.78744), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0054-loss_val=1.7874-metric_val=0.5843.ckpt" as top 3
# Epoch 55:  50%|▌| 1/2 [00:05<00:05,  5.18s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 55: 100%|█| 2/2 [00:19<00:00,  9.94s/it, loss=1.660, v_num=ejl1, loss_val=
#                                                                                 Epoch 55, global step 55: loss_val reached 1.78935 (best 1.78744), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0055-loss_val=1.7894-metric_val=0.5858.ckpt" as top 3
# Epoch 56:  50%|▌| 1/2 [00:06<00:06,  6.63s/it, loss=1.660, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 56: 100%|█| 2/2 [00:20<00:00, 10.48s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 56, global step 56: loss_val was not in top 3
# Epoch 57:  50%|▌| 1/2 [00:06<00:06,  6.31s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 57: 100%|█| 2/2 [00:22<00:00, 11.35s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 57, global step 57: loss_val reached 1.78720 (best 1.78720), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0057-loss_val=1.7872-metric_val=0.5866.ckpt" as top 3
# Epoch 58:  50%|▌| 1/2 [00:07<00:07,  7.03s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 58: 100%|█| 2/2 [00:24<00:00, 12.29s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 58, global step 58: loss_val was not in top 3
# Epoch 59:  50%|▌| 1/2 [00:09<00:09,  9.29s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 59: 100%|█| 2/2 [00:25<00:00, 12.90s/it, loss=1.650, v_num=ejl1, loss_val=
#                                                                                 Epoch 59, global step 59: loss_val was not in top 3
# Epoch 60:  50%|▌| 1/2 [00:06<00:06,  6.42s/it, loss=1.650, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 60: 100%|█| 2/2 [00:24<00:00, 12.00s/it, loss=1.710, v_num=ejl1, loss_val=
#                                                                                 Epoch 60, global step 60: loss_val reached 1.78319 (best 1.78319), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0060-loss_val=1.7832-metric_val=0.5883.ckpt" as top 3
# Epoch 61:  50%|▌| 1/2 [00:06<00:06,  6.86s/it, loss=1.710, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 61: 100%|█| 2/2 [00:21<00:00, 10.58s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 61, global step 61: loss_val reached 1.78311 (best 1.78311), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0061-loss_val=1.7831-metric_val=0.5882.ckpt" as top 3
# Epoch 62:  50%|▌| 1/2 [00:07<00:07,  7.03s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 62: 100%|█| 2/2 [00:23<00:00, 11.59s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 62, global step 62: loss_val was not in top 3
# Epoch 63:  50%|▌| 1/2 [00:06<00:06,  6.02s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 63: 100%|█| 2/2 [00:22<00:00, 11.10s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 63, global step 63: loss_val was not in top 3
# Epoch 64:  50%|▌| 1/2 [00:08<00:08,  8.12s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 64: 100%|█| 2/2 [00:25<00:00, 12.55s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 64, global step 64: loss_val was not in top 3
# Epoch 65:  50%|▌| 1/2 [00:07<00:07,  7.27s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 65: 100%|█| 2/2 [00:25<00:00, 12.60s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 65, global step 65: loss_val was not in top 3
# Epoch 66:  50%|▌| 1/2 [00:06<00:06,  6.67s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 66: 100%|█| 2/2 [00:24<00:00, 12.05s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 66, global step 66: loss_val was not in top 3
# Epoch 67:  50%|▌| 1/2 [00:07<00:07,  7.33s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 67: 100%|█| 2/2 [00:23<00:00, 11.90s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 67, global step 67: loss_val was not in top 3
# Epoch 68:  50%|▌| 1/2 [00:05<00:05,  5.86s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 68: 100%|█| 2/2 [00:22<00:00, 11.15s/it, loss=1.610, v_num=ejl1, loss_val=
#                                                                                 Epoch 68, global step 68: loss_val was not in top 3
# Epoch 69:  50%|▌| 1/2 [00:09<00:09,  9.49s/it, loss=1.610, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 69: 100%|█| 2/2 [00:25<00:00, 12.68s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 69, global step 69: loss_val was not in top 3
# Epoch 70:  50%|▌| 1/2 [00:07<00:07,  7.52s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 70: 100%|█| 2/2 [00:24<00:00, 12.39s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 70, global step 70: loss_val was not in top 3
# Epoch 71:  50%|▌| 1/2 [00:08<00:08,  8.58s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 71: 100%|█| 2/2 [00:24<00:00, 12.49s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 71, global step 71: loss_val was not in top 3
# Epoch 72:  50%|▌| 1/2 [00:05<00:05,  5.81s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 72: 100%|█| 2/2 [00:22<00:00, 11.13s/it, loss=1.650, v_num=ejl1, loss_val=
#                                                                                 Epoch 72, global step 72: loss_val was not in top 3
# Epoch 73:  50%|▌| 1/2 [00:05<00:05,  5.93s/it, loss=1.650, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 73: 100%|█| 2/2 [00:22<00:00, 11.00s/it, loss=1.610, v_num=ejl1, loss_val=
#                                                                                 Epoch 73, global step 73: loss_val was not in top 3
# Epoch 74:  50%|▌| 1/2 [00:08<00:08,  8.07s/it, loss=1.610, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 74: 100%|█| 2/2 [00:25<00:00, 12.53s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 74, global step 74: loss_val was not in top 3
# Epoch 75:  50%|▌| 1/2 [00:06<00:06,  6.09s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 75: 100%|█| 2/2 [00:22<00:00, 11.27s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 75, global step 75: loss_val was not in top 3
# Epoch 76:  50%|▌| 1/2 [00:07<00:07,  7.49s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 76: 100%|█| 2/2 [00:23<00:00, 11.76s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 76, global step 76: loss_val was not in top 3
# Epoch 77:  50%|▌| 1/2 [00:10<00:10, 10.29s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 77: 100%|█| 2/2 [00:26<00:00, 13.34s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 77, global step 77: loss_val was not in top 3
# Epoch 78:  50%|▌| 1/2 [00:07<00:07,  7.80s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 78: 100%|█| 2/2 [00:23<00:00, 11.93s/it, loss=1.660, v_num=ejl1, loss_val=
#                                                                                 Epoch 78, global step 78: loss_val was not in top 3
# Epoch 79:  50%|▌| 1/2 [00:09<00:09,  9.19s/it, loss=1.660, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 79: 100%|█| 2/2 [00:30<00:00, 15.29s/it, loss=1.660, v_num=ejl1, loss_val=
#                                                                                 Epoch 79, global step 79: loss_val was not in top 3
# Epoch 80:  50%|▌| 1/2 [00:09<00:09,  9.05s/it, loss=1.660, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 80: 100%|█| 2/2 [00:25<00:00, 12.76s/it, loss=1.670, v_num=ejl1, loss_val=
#                                                                                 Epoch 80, global step 80: loss_val was not in top 3
# Epoch 81:  50%|▌| 1/2 [00:05<00:05,  5.47s/it, loss=1.670, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 81: 100%|█| 2/2 [00:20<00:00, 10.44s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 81, global step 81: loss_val was not in top 3
# Epoch 82:  50%|▌| 1/2 [00:06<00:06,  6.04s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 82: 100%|█| 2/2 [00:25<00:00, 12.53s/it, loss=1.660, v_num=ejl1, loss_val=
#                                                                                 Epoch 82, global step 82: loss_val was not in top 3
# Epoch 83:  50%|▌| 1/2 [00:06<00:06,  6.90s/it, loss=1.660, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 83: 100%|█| 2/2 [00:23<00:00, 11.87s/it, loss=1.700, v_num=ejl1, loss_val=
#                                                                                 Epoch 83, global step 83: loss_val reached 1.78310 (best 1.78310), saving model to "logs/Retina/2pxaejl1/checkpoints/epoch=0083-loss_val=1.7831-metric_val=0.5861.ckpt" as top 3
# Epoch 84:  50%|▌| 1/2 [00:04<00:04,  4.92s/it, loss=1.700, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 84: 100%|█| 2/2 [00:20<00:00, 10.49s/it, loss=1.650, v_num=ejl1, loss_val=
#                                                                                 Epoch 84, global step 84: loss_val was not in top 3
# Epoch 85:  50%|▌| 1/2 [00:07<00:07,  7.22s/it, loss=1.650, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 85: 100%|█| 2/2 [00:23<00:00, 11.60s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 85, global step 85: loss_val was not in top 3
# Epoch 86:  50%|▌| 1/2 [00:06<00:06,  6.26s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 86: 100%|█| 2/2 [00:22<00:00, 11.00s/it, loss=1.690, v_num=ejl1, loss_val=
#                                                                                 Epoch 86, global step 86: loss_val was not in top 3
# Epoch 87:  50%|▌| 1/2 [00:06<00:06,  6.41s/it, loss=1.690, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 87: 100%|█| 2/2 [00:21<00:00, 10.93s/it, loss=1.610, v_num=ejl1, loss_val=
#                                                                                 Epoch 87, global step 87: loss_val was not in top 3
# Epoch 88:  50%|▌| 1/2 [00:05<00:05,  5.97s/it, loss=1.610, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 88: 100%|█| 2/2 [00:21<00:00, 10.88s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 88, global step 88: loss_val was not in top 3
# Epoch 89:  50%|▌| 1/2 [00:07<00:07,  7.17s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 89: 100%|█| 2/2 [00:23<00:00, 11.81s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 89, global step 89: loss_val was not in top 3
# Epoch 90:  50%|▌| 1/2 [00:06<00:06,  6.48s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 90: 100%|█| 2/2 [00:21<00:00, 10.95s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 90, global step 90: loss_val was not in top 3
# Epoch 91:  50%|▌| 1/2 [00:05<00:05,  5.31s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 91: 100%|█| 2/2 [00:20<00:00, 10.43s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 91, global step 91: loss_val was not in top 3
# Epoch 92:  50%|▌| 1/2 [00:06<00:06,  6.68s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 92: 100%|█| 2/2 [00:22<00:00, 11.11s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 92, global step 92: loss_val was not in top 3
# Epoch 93:  50%|▌| 1/2 [00:08<00:08,  8.15s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 93: 100%|█| 2/2 [00:24<00:00, 12.12s/it, loss=1.620, v_num=ejl1, loss_val=
#                                                                                 Epoch 93, global step 93: loss_val was not in top 3
# Epoch 94:  50%|▌| 1/2 [00:06<00:06,  6.34s/it, loss=1.620, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 94: 100%|█| 2/2 [00:22<00:00, 11.37s/it, loss=1.630, v_num=ejl1, loss_val=
#                                                                                 Epoch 94, global step 94: loss_val was not in top 3
# Epoch 95:  50%|▌| 1/2 [00:05<00:05,  5.97s/it, loss=1.630, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 95: 100%|█| 2/2 [00:21<00:00, 10.84s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 95, global step 95: loss_val was not in top 3
# Epoch 96:  50%|▌| 1/2 [00:06<00:06,  6.17s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 96: 100%|█| 2/2 [00:22<00:00, 11.17s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 96, global step 96: loss_val was not in top 3
# Epoch 97:  50%|▌| 1/2 [00:06<00:06,  6.88s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 97: 100%|█| 2/2 [00:23<00:00, 11.55s/it, loss=1.640, v_num=ejl1, loss_val=
#                                                                                 Epoch 97, global step 97: loss_val was not in top 3
# Epoch 98:  50%|▌| 1/2 [00:07<00:07,  7.33s/it, loss=1.640, v_num=ejl1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Sweeps

# %%
# generate sweep using sweep.yaml
# !python -m wandb sweep sweep.yaml

# %%
# Run sweeps
# !CUDA_VISIBLE_DEVICES=0 python -m wandb agent [your_sweep_address]
# !CUDA_VISIBLE_DEVICES=0 python -m wandb agent keewonshin/Retina/rdzpb4mr
