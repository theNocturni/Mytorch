# %% [markdown]
# # Settings

# %%
# gpu status
# !nvidia-smi

# %%
# install packages
# !pip install -r requirements.txt --user --quiet -U
# !pip uninstall torch -y
# !pip install torch==1.8.0
# !apt updates

# %%
# !sudo apt update
# !sudo apt install libgl1-mesa-glx ffmpeg libsm6 libxext6 -y

# %%
# log into weight and bias, if error occurs, please reset your jupyter kernal
import wandb
wandb.login()

# %% [markdown]
# # Train

# %%
# run training
# !CUDA_VISIBLE_DEVICES=0 python train.py --project Retina \
                                        --data_dir ../Retina/dataset/DRIVE \
                                        --data_module dataset \
                                        --net waveletunet_r2att \
                                        --net_inputch 3 \
                                        --net_outputch 3 \
                                        --net_norm group \
                                        --lossfn BoundaryCELoss \
                                        --precision 16 \
                                        --data_patchsize 128_128 \
                                        --batch_size 24
# Out:
# args: Namespace(batch_size=24, data_cropsize=None, data_dir='../Retina/dataset/DRIVE', data_module='dataset', data_padsize=None, data_patchsize='128_128', data_resize=None, experiment_name=None, lossfn='BoundaryCELoss', lr=0, net='waveletunet_r2att', net_ckpt=None, net_inputch=3, net_norm='group', net_outputch=3, precision=16, project='Retina')
#
# net_norms were replaced to group normalizations
# project Retina
# Current Experiment: DatasetDRIVE_Netwaveletunet_r2att_Netinputch3_Netoutputch3_LossBoundaryCELoss_Lr0_Precision16_Patchsize128_128_PrefixNone_
#  ****************************************************************************************************
# wandb: Currently logged in as: keewonshin (use `wandb login --relogin` to force relogin)
# /opt/conda/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# /opt/conda/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run DatasetDRIVE_Netwaveletunet_r2att_Netinputch3_Netoutputch3_LossBoundaryCELoss_Lr0_Precision16_Patchsize128_128_PrefixNone_
# wandb:  View project at https://wandb.ai/keewonshin/Retina
# wandb:  View run at https://wandb.ai/keewonshin/Retina/runs/wodqjvyz
# wandb: Run data is saved locally in logs/wandb/run-20210805_094537-wodqjvyz
# wandb: Run `wandb offline` to turn off syncing.
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# total counts of dataset x 18, y 18
# total counts of dataset x 2, y 2
# total counts of dataset x 20, y 20
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name   | Type              | Params
# ---------------------------------------------
# 0 | lossfn | BoundaryCELoss    | 0
# 1 | net    | waveletunet_r2att | 223 M
# 2 | metric | F1                | 0
# ---------------------------------------------
# 223 M     Trainable params
# 0         Non-trainable params
# 223 M     Total params
# 893.413   Total estimated model params size (MB)
# Epoch 0:  50%|▌| 1/2 [00:10<00:10, 10.37s/it, loss=1.96, v_num=jvyz, loss_val=2./home/kevin/.local/lib/python3.8/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
#
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█| 2/2 [00:44<00:00, 22.09s/it, loss=1.960, v_num=jvyz, loss_val=2
#                                                                                 Epoch 0, global step 0: loss_val reached 1.99675 (best 1.99675), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0000-loss_val=1.9967-metric_val=0.1910.ckpt" as top 3
# Epoch 1:  50%|▌| 1/2 [00:07<00:07,  7.78s/it, loss=1.960, v_num=jvyz, loss_val=2
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 2/2 [00:39<00:00, 19.91s/it, loss=1.960, v_num=jvyz, loss_val=1
#                                                                                 Epoch 1, global step 1: loss_val reached 1.99454 (best 1.99454), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0001-loss_val=1.9945-metric_val=0.1933.ckpt" as top 3
# Epoch 2:  50%|▌| 1/2 [00:12<00:12, 12.32s/it, loss=1.960, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 2/2 [00:43<00:00, 21.64s/it, loss=1.970, v_num=jvyz, loss_val=1
#                                                                                 Epoch 2, global step 2: loss_val reached 1.98798 (best 1.98798), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0002-loss_val=1.9880-metric_val=0.2009.ckpt" as top 3
# Epoch 3:  50%|▌| 1/2 [00:07<00:07,  7.93s/it, loss=1.970, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 2/2 [00:39<00:00, 19.69s/it, loss=1.980, v_num=jvyz, loss_val=1
#                                                                                 Epoch 3, global step 3: loss_val reached 1.97583 (best 1.97583), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0003-loss_val=1.9758-metric_val=0.2178.ckpt" as top 3
# Epoch 4:  50%|▌| 1/2 [00:08<00:08,  8.26s/it, loss=1.980, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 2/2 [00:30<00:00, 15.12s/it, loss=1.930, v_num=jvyz, loss_val=1
#                                                                                 Epoch 4, global step 4: loss_val reached 1.95749 (best 1.95749), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0004-loss_val=1.9575-metric_val=0.2514.ckpt" as top 3
# Epoch 5:  50%|▌| 1/2 [00:07<00:07,  7.91s/it, loss=1.930, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 2/2 [00:29<00:00, 14.98s/it, loss=1.910, v_num=jvyz, loss_val=1
#                                                                                 Epoch 5, global step 5: loss_val reached 1.93346 (best 1.93346), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0005-loss_val=1.9335-metric_val=0.3113.ckpt" as top 3
# Epoch 6:  50%|▌| 1/2 [00:07<00:07,  7.10s/it, loss=1.910, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 2/2 [00:28<00:00, 14.30s/it, loss=1.890, v_num=jvyz, loss_val=1
#                                                                                 Epoch 6, global step 6: loss_val reached 1.90462 (best 1.90462), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0006-loss_val=1.9046-metric_val=0.3859.ckpt" as top 3
# Epoch 7:  50%|▌| 1/2 [00:07<00:07,  7.53s/it, loss=1.890, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 2/2 [00:28<00:00, 14.45s/it, loss=1.810, v_num=jvyz, loss_val=1
#                                                                                 Epoch 7, global step 7: loss_val reached 1.87296 (best 1.87296), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0007-loss_val=1.8730-metric_val=0.4652.ckpt" as top 3
# Epoch 8:  50%|▌| 1/2 [00:11<00:11, 11.25s/it, loss=1.810, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 2/2 [00:33<00:00, 16.90s/it, loss=1.780, v_num=jvyz, loss_val=1
#                                                                                 Epoch 8, global step 8: loss_val reached 1.84117 (best 1.84117), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0008-loss_val=1.8412-metric_val=0.5182.ckpt" as top 3
# Epoch 9:  50%|▌| 1/2 [00:17<00:17, 17.96s/it, loss=1.780, v_num=jvyz, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 2/2 [00:48<00:00, 24.34s/it, loss=1.750, v_num=jvyz, loss_val=1
#                                                                                 Epoch 9, global step 9: loss_val reached 1.81256 (best 1.81256), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0009-loss_val=1.8126-metric_val=0.5498.ckpt" as top 3
# Epoch 10:  50%|▌| 1/2 [00:08<00:08,  8.90s/it, loss=1.750, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 2/2 [00:40<00:00, 20.06s/it, loss=1.720, v_num=jvyz, loss_val=
#                                                                                 Epoch 10, global step 10: loss_val reached 1.79020 (best 1.79020), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0010-loss_val=1.7902-metric_val=0.5791.ckpt" as top 3
# Epoch 11:  50%|▌| 1/2 [00:08<00:08,  8.85s/it, loss=1.720, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 2/2 [00:39<00:00, 19.68s/it, loss=1.650, v_num=jvyz, loss_val=
#                                                                                 Epoch 11, global step 11: loss_val reached 1.77687 (best 1.77687), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0011-loss_val=1.7769-metric_val=0.5910.ckpt" as top 3
# Epoch 12:  50%|▌| 1/2 [00:08<00:08,  8.18s/it, loss=1.650, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 2/2 [00:38<00:00, 19.10s/it, loss=1.600, v_num=jvyz, loss_val=
#                                                                                 Epoch 12, global step 12: loss_val reached 1.77062 (best 1.77062), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0012-loss_val=1.7706-metric_val=0.5943.ckpt" as top 3
# Epoch 13:  50%|▌| 1/2 [00:07<00:07,  7.80s/it, loss=1.600, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 2/2 [00:37<00:00, 18.72s/it, loss=1.610, v_num=jvyz, loss_val=
#                                                                                 Epoch 13, global step 13: loss_val reached 1.76771 (best 1.76771), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0013-loss_val=1.7677-metric_val=0.5944.ckpt" as top 3
# Epoch 14:  50%|▌| 1/2 [00:08<00:08,  8.28s/it, loss=1.610, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 2/2 [00:38<00:00, 19.32s/it, loss=1.550, v_num=jvyz, loss_val=
#                                                                                 Epoch 14, global step 14: loss_val reached 1.76635 (best 1.76635), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0014-loss_val=1.7664-metric_val=0.5932.ckpt" as top 3
# Epoch 15:  50%|▌| 1/2 [00:09<00:09,  9.26s/it, loss=1.550, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 2/2 [00:36<00:00, 18.16s/it, loss=1.610, v_num=jvyz, loss_val=
#                                                                                 Epoch 15, global step 15: loss_val reached 1.76562 (best 1.76562), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0015-loss_val=1.7656-metric_val=0.5902.ckpt" as top 3
# Epoch 16:  50%|▌| 1/2 [00:08<00:08,  8.71s/it, loss=1.610, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 2/2 [00:31<00:00, 15.55s/it, loss=1.590, v_num=jvyz, loss_val=
#                                                                                 Epoch 16, global step 16: loss_val reached 1.76511 (best 1.76511), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0016-loss_val=1.7651-metric_val=0.5882.ckpt" as top 3
# Epoch 17:  50%|▌| 1/2 [00:07<00:07,  7.16s/it, loss=1.590, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 2/2 [00:29<00:00, 14.67s/it, loss=1.520, v_num=jvyz, loss_val=
#                                                                                 Epoch 17, global step 17: loss_val reached 1.76515 (best 1.76511), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0017-loss_val=1.7652-metric_val=0.5829.ckpt" as top 3
# Epoch 18:  50%|▌| 1/2 [00:09<00:09,  9.06s/it, loss=1.520, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 2/2 [00:31<00:00, 15.59s/it, loss=1.650, v_num=jvyz, loss_val=
#                                                                                 Epoch 18, global step 18: loss_val reached 1.76544 (best 1.76511), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0018-loss_val=1.7654-metric_val=0.5784.ckpt" as top 3
# Epoch 19:  50%|▌| 1/2 [00:16<00:16, 16.81s/it, loss=1.650, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 2/2 [00:39<00:00, 19.98s/it, loss=1.550, v_num=jvyz, loss_val=
#                                                                                 Epoch 19, global step 19: loss_val was not in top 3
# Epoch 20:  50%|▌| 1/2 [00:09<00:09,  9.57s/it, loss=1.550, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 2/2 [00:32<00:00, 16.21s/it, loss=1.570, v_num=jvyz, loss_val=
#                                                                                 Epoch 20, global step 20: loss_val reached 1.76477 (best 1.76477), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0020-loss_val=1.7648-metric_val=0.5788.ckpt" as top 3
# Epoch 21:  50%|▌| 1/2 [00:07<00:07,  7.57s/it, loss=1.570, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 2/2 [00:29<00:00, 14.70s/it, loss=1.510, v_num=jvyz, loss_val=
#                                                                                 Epoch 21, global step 21: loss_val reached 1.76341 (best 1.76341), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0021-loss_val=1.7634-metric_val=0.5813.ckpt" as top 3
# Epoch 22:  50%|▌| 1/2 [00:07<00:07,  7.64s/it, loss=1.510, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 2/2 [00:30<00:00, 15.18s/it, loss=1.520, v_num=jvyz, loss_val=
#                                                                                 Epoch 22, global step 22: loss_val reached 1.76130 (best 1.76130), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0022-loss_val=1.7613-metric_val=0.5828.ckpt" as top 3
# Epoch 23:  50%|▌| 1/2 [00:08<00:08,  8.28s/it, loss=1.520, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|█| 2/2 [00:30<00:00, 15.13s/it, loss=1.470, v_num=jvyz, loss_val=
#                                                                                 Epoch 23, global step 23: loss_val reached 1.75943 (best 1.75943), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0023-loss_val=1.7594-metric_val=0.5847.ckpt" as top 3
# Epoch 24:  50%|▌| 1/2 [00:07<00:07,  7.83s/it, loss=1.470, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|█| 2/2 [00:38<00:00, 19.17s/it, loss=1.480, v_num=jvyz, loss_val=
#                                                                                 Epoch 24, global step 24: loss_val reached 1.75802 (best 1.75802), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0024-loss_val=1.7580-metric_val=0.5871.ckpt" as top 3
# Epoch 25:  50%|▌| 1/2 [00:08<00:08,  8.79s/it, loss=1.480, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 25: 100%|█| 2/2 [00:38<00:00, 19.06s/it, loss=1.550, v_num=jvyz, loss_val=
#                                                                                 Epoch 25, global step 25: loss_val reached 1.75656 (best 1.75656), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0025-loss_val=1.7566-metric_val=0.5890.ckpt" as top 3
# Epoch 26:  50%|▌| 1/2 [00:08<00:08,  8.64s/it, loss=1.550, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 26: 100%|█| 2/2 [00:39<00:00, 19.58s/it, loss=1.480, v_num=jvyz, loss_val=
#                                                                                 Epoch 26, global step 26: loss_val reached 1.75542 (best 1.75542), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0026-loss_val=1.7554-metric_val=0.5898.ckpt" as top 3
# Epoch 27:  50%|▌| 1/2 [00:10<00:10, 10.42s/it, loss=1.480, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 27: 100%|█| 2/2 [00:40<00:00, 20.14s/it, loss=1.530, v_num=jvyz, loss_val=
#                                                                                 Epoch 27, global step 27: loss_val reached 1.75421 (best 1.75421), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0027-loss_val=1.7542-metric_val=0.5902.ckpt" as top 3
# Epoch 28:  50%|▌| 1/2 [00:08<00:08,  8.33s/it, loss=1.530, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 28: 100%|█| 2/2 [00:38<00:00, 19.35s/it, loss=1.530, v_num=jvyz, loss_val=
#                                                                                 Epoch 28, global step 28: loss_val reached 1.75263 (best 1.75263), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0028-loss_val=1.7526-metric_val=0.5899.ckpt" as top 3
# Epoch 29:  50%|▌| 1/2 [00:19<00:19, 19.28s/it, loss=1.530, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 29: 100%|█| 2/2 [00:48<00:00, 24.41s/it, loss=1.470, v_num=jvyz, loss_val=
#                                                                                 Epoch 29, global step 29: loss_val reached 1.75151 (best 1.75151), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0029-loss_val=1.7515-metric_val=0.5887.ckpt" as top 3
# Epoch 30:  50%|▌| 1/2 [00:07<00:07,  7.84s/it, loss=1.470, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 30: 100%|█| 2/2 [00:28<00:00, 14.44s/it, loss=1.500, v_num=jvyz, loss_val=
#                                                                                 Epoch 30, global step 30: loss_val reached 1.75078 (best 1.75078), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0030-loss_val=1.7508-metric_val=0.5865.ckpt" as top 3
# Epoch 31:  50%|▌| 1/2 [00:07<00:07,  7.15s/it, loss=1.500, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 31: 100%|█| 2/2 [00:29<00:00, 14.56s/it, loss=1.540, v_num=jvyz, loss_val=
#                                                                                 Epoch 31, global step 31: loss_val reached 1.74932 (best 1.74932), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0031-loss_val=1.7493-metric_val=0.5858.ckpt" as top 3
# Epoch 32:  50%|▌| 1/2 [00:08<00:08,  8.76s/it, loss=1.540, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 32: 100%|█| 2/2 [00:30<00:00, 15.13s/it, loss=1.580, v_num=jvyz, loss_val=
#                                                                                 Epoch 32, global step 32: loss_val reached 1.74656 (best 1.74656), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0032-loss_val=1.7466-metric_val=0.5866.ckpt" as top 3
# Epoch 33:  50%|▌| 1/2 [00:08<00:08,  8.94s/it, loss=1.580, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 33: 100%|█| 2/2 [00:31<00:00, 15.57s/it, loss=1.480, v_num=jvyz, loss_val=
#                                                                                 Epoch 33, global step 33: loss_val reached 1.74369 (best 1.74369), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0033-loss_val=1.7437-metric_val=0.5883.ckpt" as top 3
# Epoch 34:  50%|▌| 1/2 [00:09<00:09,  9.53s/it, loss=1.480, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 34: 100%|█| 2/2 [00:31<00:00, 15.51s/it, loss=1.540, v_num=jvyz, loss_val=
#                                                                                 Epoch 34, global step 34: loss_val reached 1.74076 (best 1.74076), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0034-loss_val=1.7408-metric_val=0.5888.ckpt" as top 3
# Epoch 35:  50%|▌| 1/2 [00:08<00:08,  8.89s/it, loss=1.540, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 35: 100%|█| 2/2 [00:30<00:00, 15.10s/it, loss=1.500, v_num=jvyz, loss_val=
#                                                                                 Epoch 35, global step 35: loss_val reached 1.73814 (best 1.73814), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0035-loss_val=1.7381-metric_val=0.5885.ckpt" as top 3
# Epoch 36:  50%|▌| 1/2 [00:09<00:09,  9.13s/it, loss=1.500, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 36: 100%|█| 2/2 [00:38<00:00, 19.24s/it, loss=1.500, v_num=jvyz, loss_val=
#                                                                                 Epoch 36, global step 36: loss_val reached 1.73524 (best 1.73524), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0036-loss_val=1.7352-metric_val=0.5889.ckpt" as top 3
# Epoch 37:  50%|▌| 1/2 [00:09<00:09,  9.11s/it, loss=1.500, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 37: 100%|█| 2/2 [00:38<00:00, 19.44s/it, loss=1.440, v_num=jvyz, loss_val=
#                                                                                 Epoch 37, global step 37: loss_val reached 1.73198 (best 1.73198), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0037-loss_val=1.7320-metric_val=0.5896.ckpt" as top 3
# Epoch 38:  50%|▌| 1/2 [00:07<00:07,  7.74s/it, loss=1.440, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 38: 100%|█| 2/2 [00:38<00:00, 19.17s/it, loss=1.510, v_num=jvyz, loss_val=
#                                                                                 Epoch 38, global step 38: loss_val reached 1.72904 (best 1.72904), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0038-loss_val=1.7290-metric_val=0.5894.ckpt" as top 3
# Epoch 39:  50%|▌| 1/2 [00:19<00:19, 19.01s/it, loss=1.510, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 39: 100%|█| 2/2 [00:51<00:00, 25.55s/it, loss=1.510, v_num=jvyz, loss_val=
#                                                                                 Epoch 39, global step 39: loss_val reached 1.72608 (best 1.72608), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0039-loss_val=1.7261-metric_val=0.5896.ckpt" as top 3
# Epoch 40:  50%|▌| 1/2 [00:08<00:08,  8.41s/it, loss=1.510, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 40: 100%|█| 2/2 [00:39<00:00, 19.87s/it, loss=1.510, v_num=jvyz, loss_val=
#                                                                                 Epoch 40, global step 40: loss_val reached 1.72314 (best 1.72314), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0040-loss_val=1.7231-metric_val=0.5890.ckpt" as top 3
# Epoch 41:  50%|▌| 1/2 [00:08<00:08,  8.31s/it, loss=1.510, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 41: 100%|█| 2/2 [00:39<00:00, 19.53s/it, loss=1.520, v_num=jvyz, loss_val=
#                                                                                 Epoch 41, global step 41: loss_val reached 1.72135 (best 1.72135), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0041-loss_val=1.7213-metric_val=0.5872.ckpt" as top 3
# Epoch 42:  50%|▌| 1/2 [00:07<00:07,  7.41s/it, loss=1.520, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 42: 100%|█| 2/2 [00:38<00:00, 19.07s/it, loss=1.510, v_num=jvyz, loss_val=
#                                                                                 Epoch 42, global step 42: loss_val reached 1.71884 (best 1.71884), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0042-loss_val=1.7188-metric_val=0.5862.ckpt" as top 3
# Epoch 43:  50%|▌| 1/2 [00:09<00:09,  9.14s/it, loss=1.510, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 43: 100%|█| 2/2 [00:39<00:00, 19.62s/it, loss=1.530, v_num=jvyz, loss_val=
#                                                                                 Epoch 43, global step 43: loss_val reached 1.71537 (best 1.71537), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0043-loss_val=1.7154-metric_val=0.5868.ckpt" as top 3
# Epoch 44:  50%|▌| 1/2 [00:08<00:08,  8.04s/it, loss=1.530, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 44: 100%|█| 2/2 [00:38<00:00, 19.38s/it, loss=1.530, v_num=jvyz, loss_val=
#                                                                                 Epoch 44, global step 44: loss_val reached 1.71115 (best 1.71115), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0044-loss_val=1.7112-metric_val=0.5887.ckpt" as top 3
# Epoch 45:  50%|▌| 1/2 [00:09<00:09,  9.59s/it, loss=1.530, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 45: 100%|█| 2/2 [00:41<00:00, 20.53s/it, loss=1.540, v_num=jvyz, loss_val=
#                                                                                 Epoch 45, global step 45: loss_val reached 1.70806 (best 1.70806), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0045-loss_val=1.7081-metric_val=0.5905.ckpt" as top 3
# Epoch 46:  50%|▌| 1/2 [00:07<00:07,  7.84s/it, loss=1.540, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 46: 100%|█| 2/2 [00:39<00:00, 19.68s/it, loss=1.560, v_num=jvyz, loss_val=
#                                                                                 Epoch 46, global step 46: loss_val reached 1.70517 (best 1.70517), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0046-loss_val=1.7052-metric_val=0.5911.ckpt" as top 3
# Epoch 47:  50%|▌| 1/2 [00:08<00:08,  8.64s/it, loss=1.560, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 47: 100%|█| 2/2 [00:31<00:00, 15.77s/it, loss=1.490, v_num=jvyz, loss_val=
#                                                                                 Epoch 47, global step 47: loss_val reached 1.70257 (best 1.70257), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0047-loss_val=1.7026-metric_val=0.5905.ckpt" as top 3
# Epoch 48:  50%|▌| 1/2 [00:07<00:07,  7.91s/it, loss=1.490, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 48: 100%|█| 2/2 [00:37<00:00, 18.80s/it, loss=1.490, v_num=jvyz, loss_val=
#                                                                                 Epoch 48, global step 48: loss_val reached 1.70235 (best 1.70235), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0048-loss_val=1.7023-metric_val=0.5890.ckpt" as top 3
# Epoch 49:  50%|▌| 1/2 [00:17<00:17, 17.97s/it, loss=1.490, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█| 2/2 [00:45<00:00, 22.95s/it, loss=1.530, v_num=jvyz, loss_val=
#                                                                                 Epoch 49, global step 49: loss_val reached 1.69947 (best 1.69947), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0049-loss_val=1.6995-metric_val=0.5889.ckpt" as top 3
# Epoch 50:  50%|▌| 1/2 [00:11<00:11, 11.41s/it, loss=1.530, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 50: 100%|█| 2/2 [00:40<00:00, 20.19s/it, loss=1.450, v_num=jvyz, loss_val=
#                                                                                 Epoch 50, global step 50: loss_val reached 1.69344 (best 1.69344), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0050-loss_val=1.6934-metric_val=0.5902.ckpt" as top 3
# Epoch 51:  50%|▌| 1/2 [00:09<00:09,  9.23s/it, loss=1.450, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 51: 100%|█| 2/2 [00:38<00:00, 19.20s/it, loss=1.460, v_num=jvyz, loss_val=
#                                                                                 Epoch 51, global step 51: loss_val reached 1.68876 (best 1.68876), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0051-loss_val=1.6888-metric_val=0.5920.ckpt" as top 3
# Epoch 52:  50%|▌| 1/2 [00:07<00:07,  7.92s/it, loss=1.460, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 52: 100%|█| 2/2 [00:37<00:00, 18.55s/it, loss=1.430, v_num=jvyz, loss_val=
#                                                                                 Epoch 52, global step 52: loss_val reached 1.68573 (best 1.68573), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0052-loss_val=1.6857-metric_val=0.5928.ckpt" as top 3
# Epoch 53:  50%|▌| 1/2 [00:07<00:07,  7.62s/it, loss=1.430, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 53: 100%|█| 2/2 [00:36<00:00, 18.03s/it, loss=1.470, v_num=jvyz, loss_val=
#                                                                                 Epoch 53, global step 53: loss_val reached 1.68186 (best 1.68186), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0053-loss_val=1.6819-metric_val=0.5929.ckpt" as top 3
# Epoch 54:  50%|▌| 1/2 [00:07<00:07,  7.90s/it, loss=1.470, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 54: 100%|█| 2/2 [00:37<00:00, 18.51s/it, loss=1.380, v_num=jvyz, loss_val=
#                                                                                 Epoch 54, global step 54: loss_val reached 1.68108 (best 1.68108), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0054-loss_val=1.6811-metric_val=0.5920.ckpt" as top 3
# Epoch 55:  50%|▌| 1/2 [00:07<00:07,  7.98s/it, loss=1.380, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 55: 100%|█| 2/2 [00:37<00:00, 18.87s/it, loss=1.570, v_num=jvyz, loss_val=
#                                                                                 Epoch 55, global step 55: loss_val reached 1.68174 (best 1.68108), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0055-loss_val=1.6817-metric_val=0.5911.ckpt" as top 3
# Epoch 56:  50%|▌| 1/2 [00:10<00:10, 10.23s/it, loss=1.570, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 56: 100%|█| 2/2 [00:40<00:00, 20.17s/it, loss=1.470, v_num=jvyz, loss_val=
#                                                                                 Epoch 56, global step 56: loss_val reached 1.67969 (best 1.67969), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0056-loss_val=1.6797-metric_val=0.5911.ckpt" as top 3
# Epoch 57:  50%|▌| 1/2 [00:06<00:06,  6.72s/it, loss=1.470, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 57: 100%|█| 2/2 [00:37<00:00, 18.88s/it, loss=1.420, v_num=jvyz, loss_val=
#                                                                                 Epoch 57, global step 57: loss_val reached 1.67412 (best 1.67412), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0057-loss_val=1.6741-metric_val=0.5922.ckpt" as top 3
# Epoch 58:  50%|▌| 1/2 [00:09<00:09,  9.61s/it, loss=1.420, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 58: 100%|█| 2/2 [00:38<00:00, 19.19s/it, loss=1.400, v_num=jvyz, loss_val=
#                                                                                 Epoch 58, global step 58: loss_val reached 1.67130 (best 1.67130), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0058-loss_val=1.6713-metric_val=0.5940.ckpt" as top 3
# Epoch 59:  50%|▌| 1/2 [00:18<00:18, 18.05s/it, loss=1.400, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 59: 100%|█| 2/2 [00:48<00:00, 24.16s/it, loss=1.430, v_num=jvyz, loss_val=
#                                                                                 Epoch 59, global step 59: loss_val reached 1.66984 (best 1.66984), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0059-loss_val=1.6698-metric_val=0.5944.ckpt" as top 3
# Epoch 60:  50%|▌| 1/2 [00:07<00:07,  7.09s/it, loss=1.430, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 60: 100%|█| 2/2 [00:35<00:00, 17.77s/it, loss=1.500, v_num=jvyz, loss_val=
#                                                                                 Epoch 60, global step 60: loss_val reached 1.66529 (best 1.66529), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0060-loss_val=1.6653-metric_val=0.5946.ckpt" as top 3
# Epoch 61:  50%|▌| 1/2 [00:09<00:09,  9.27s/it, loss=1.500, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 61: 100%|█| 2/2 [00:38<00:00, 19.48s/it, loss=1.470, v_num=jvyz, loss_val=
#                                                                                 Epoch 61, global step 61: loss_val reached 1.66085 (best 1.66085), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0061-loss_val=1.6608-metric_val=0.5944.ckpt" as top 3
# Epoch 62:  50%|▌| 1/2 [00:08<00:08,  8.16s/it, loss=1.470, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 62: 100%|█| 2/2 [00:29<00:00, 14.86s/it, loss=1.480, v_num=jvyz, loss_val=
#                                                                                 Epoch 62, global step 62: loss_val reached 1.65749 (best 1.65749), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0062-loss_val=1.6575-metric_val=0.5943.ckpt" as top 3
# Epoch 63:  50%|▌| 1/2 [00:09<00:09,  9.49s/it, loss=1.480, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 63: 100%|█| 2/2 [00:31<00:00, 15.57s/it, loss=1.460, v_num=jvyz, loss_val=
#                                                                                 Epoch 63, global step 63: loss_val reached 1.65265 (best 1.65265), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0063-loss_val=1.6527-metric_val=0.5948.ckpt" as top 3
# Epoch 64:  50%|▌| 1/2 [00:06<00:06,  6.55s/it, loss=1.460, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 64: 100%|█| 2/2 [00:31<00:00, 15.72s/it, loss=1.390, v_num=jvyz, loss_val=
#                                                                                 Epoch 64, global step 64: loss_val reached 1.64639 (best 1.64639), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0064-loss_val=1.6464-metric_val=0.5959.ckpt" as top 3
# Epoch 65:  50%|▌| 1/2 [00:09<00:09,  9.45s/it, loss=1.390, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 65: 100%|█| 2/2 [00:38<00:00, 19.00s/it, loss=1.410, v_num=jvyz, loss_val=
#                                                                                 Epoch 65, global step 65: loss_val reached 1.64030 (best 1.64030), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0065-loss_val=1.6403-metric_val=0.5972.ckpt" as top 3
# Epoch 66:  50%|▌| 1/2 [00:08<00:08,  8.23s/it, loss=1.410, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 66: 100%|█| 2/2 [00:39<00:00, 19.61s/it, loss=1.430, v_num=jvyz, loss_val=
#                                                                                 Epoch 66, global step 66: loss_val reached 1.63434 (best 1.63434), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0066-loss_val=1.6343-metric_val=0.5982.ckpt" as top 3
# Epoch 67:  50%|▌| 1/2 [00:08<00:08,  8.54s/it, loss=1.430, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 67: 100%|█| 2/2 [00:40<00:00, 20.12s/it, loss=1.340, v_num=jvyz, loss_val=
#                                                                                 Epoch 67, global step 67: loss_val reached 1.63012 (best 1.63012), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0067-loss_val=1.6301-metric_val=0.5983.ckpt" as top 3
# Epoch 68:  50%|▌| 1/2 [00:08<00:08,  8.89s/it, loss=1.340, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 68: 100%|█| 2/2 [00:39<00:00, 19.63s/it, loss=1.350, v_num=jvyz, loss_val=
#                                                                                 Epoch 68, global step 68: loss_val reached 1.62667 (best 1.62667), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0068-loss_val=1.6267-metric_val=0.5987.ckpt" as top 3
# Epoch 69:  50%|▌| 1/2 [00:18<00:18, 18.89s/it, loss=1.350, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 69: 100%|█| 2/2 [00:49<00:00, 24.93s/it, loss=1.460, v_num=jvyz, loss_val=
#                                                                                 Epoch 69, global step 69: loss_val reached 1.62149 (best 1.62149), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0069-loss_val=1.6215-metric_val=0.5994.ckpt" as top 3
# Epoch 70:  50%|▌| 1/2 [00:07<00:07,  7.58s/it, loss=1.460, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 70: 100%|█| 2/2 [00:38<00:00, 19.48s/it, loss=1.420, v_num=jvyz, loss_val=
#                                                                                 Epoch 70, global step 70: loss_val reached 1.61707 (best 1.61707), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0070-loss_val=1.6171-metric_val=0.5996.ckpt" as top 3
# Epoch 71:  50%|▌| 1/2 [00:07<00:07,  7.71s/it, loss=1.420, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 71: 100%|█| 2/2 [00:38<00:00, 19.06s/it, loss=1.320, v_num=jvyz, loss_val=
#                                                                                 Epoch 71, global step 71: loss_val reached 1.61460 (best 1.61460), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0071-loss_val=1.6146-metric_val=0.5994.ckpt" as top 3
# Epoch 72:  50%|▌| 1/2 [00:07<00:07,  7.85s/it, loss=1.320, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 72: 100%|█| 2/2 [00:39<00:00, 19.84s/it, loss=1.310, v_num=jvyz, loss_val=
#                                                                                 Epoch 72, global step 72: loss_val reached 1.61428 (best 1.61428), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0072-loss_val=1.6143-metric_val=0.5992.ckpt" as top 3
# Epoch 73:  50%|▌| 1/2 [00:06<00:06,  6.86s/it, loss=1.310, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 73: 100%|█| 2/2 [00:37<00:00, 18.70s/it, loss=1.340, v_num=jvyz, loss_val=
#                                                                                 Epoch 73, global step 73: loss_val reached 1.61265 (best 1.61265), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0073-loss_val=1.6127-metric_val=0.5987.ckpt" as top 3
# Epoch 74:  50%|▌| 1/2 [00:08<00:08,  8.88s/it, loss=1.340, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 74: 100%|█| 2/2 [00:37<00:00, 18.95s/it, loss=1.370, v_num=jvyz, loss_val=
#                                                                                 Epoch 74, global step 74: loss_val reached 1.60994 (best 1.60994), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0074-loss_val=1.6099-metric_val=0.5978.ckpt" as top 3
# Epoch 75:  50%|▌| 1/2 [00:08<00:08,  8.73s/it, loss=1.370, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 75: 100%|█| 2/2 [00:30<00:00, 15.21s/it, loss=1.320, v_num=jvyz, loss_val=
#                                                                                 Epoch 75, global step 75: loss_val reached 1.60670 (best 1.60670), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0075-loss_val=1.6067-metric_val=0.5975.ckpt" as top 3
# Epoch 76:  50%|▌| 1/2 [00:09<00:09,  9.42s/it, loss=1.320, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 76: 100%|█| 2/2 [00:31<00:00, 15.61s/it, loss=1.380, v_num=jvyz, loss_val=
#                                                                                 Epoch 76, global step 76: loss_val reached 1.60241 (best 1.60241), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0076-loss_val=1.6024-metric_val=0.5978.ckpt" as top 3
# Epoch 77:  50%|▌| 1/2 [00:07<00:07,  7.48s/it, loss=1.380, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 77: 100%|█| 2/2 [00:28<00:00, 14.46s/it, loss=1.420, v_num=jvyz, loss_val=
#                                                                                 Epoch 77, global step 77: loss_val reached 1.59848 (best 1.59848), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0077-loss_val=1.5985-metric_val=0.5978.ckpt" as top 3
# Epoch 78:  50%|▌| 1/2 [00:08<00:08,  8.87s/it, loss=1.420, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 78: 100%|█| 2/2 [00:31<00:00, 15.61s/it, loss=1.310, v_num=jvyz, loss_val=
#                                                                                 Epoch 78, global step 78: loss_val reached 1.59710 (best 1.59710), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0078-loss_val=1.5971-metric_val=0.5976.ckpt" as top 3
# Epoch 79:  50%|▌| 1/2 [00:16<00:16, 16.29s/it, loss=1.310, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 79: 100%|█| 2/2 [00:46<00:00, 23.35s/it, loss=1.330, v_num=jvyz, loss_val=
#                                                                                 Epoch 79, global step 79: loss_val reached 1.59865 (best 1.59710), saving model to "logs/Retina/wodqjvyz/checkpoints/epoch=0079-loss_val=1.5987-metric_val=0.5971.ckpt" as top 3
# Epoch 80:  50%|▌| 1/2 [00:08<00:08,  8.63s/it, loss=1.330, v_num=jvyz, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Sweeps

# %%
# generate sweep using sweep.yaml
# !python -m wandb sweep sweep.yaml

# %%
# Run sweeps
# !CUDA_VISIBLE_DEVICES=0 python -m wandb agent [your_sweep_address]
# !CUDA_VISIBLE_DEVICES=0 python -m wandb agent keewonshin/Retina/rdzpb4mr
