# %%
# !nvidia-smi

# %%
# !pip install -r requirements.txt --user

# %%
import wandb
wandb.login()

# %%
# !CUDA_VISIBLE_DEVICES=1 python train.py --data_dir ../Class1 \
                                        --data_module dataset \
                                        --net manet_eb5_batch \
                                        --net_inputch 3 \
                                        --net_outputch 2 \
                                        --lossfn BoundaryCELoss \
                                        --precision 16 \
                                        --data_padsize 1200_2048 \
                                        --data_cropsize 1024_2048 \
                                        --data_resize 256_512 \
                                        --data_patchsize 256_512 \
                                        --batch_size 16
# Out:
# args: Namespace(batch_size=16, data_cropsize='1024_2048', data_dir='../Class1', data_module='dataset', data_padsize='1200_2048', data_patchsize='256_512', data_resize='256_512', experiment_name=None, finetune='False', lossfn='BoundaryCELoss', net='manet_eb5_batch', net_inputch=3, net_outputch=2, precision=16)
#
# Current Experiment: Netmanet_eb5_batch_Netinputch3_Netoutputch2_LossBoundaryCELoss_Precision16_Patchsize256_512_PrefixNone_
# wandb: Currently logged in as: keewonshin (use `wandb login --relogin` to force relogin)
# /opt/conda/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# wandb: wandb version 0.11.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ...
