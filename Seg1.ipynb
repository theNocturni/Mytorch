# %%
# !nvidia-smi

# %%
# !pip install torch==1.8.0 --user
import torch
torch.__version__

# %%
# !pip uninstall -y segmentation_models_pytorch

# %%
# !pip install torchsummary wandb --user
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch --user --quiet
# !pip install https://github.com/VincentStimper/mclahe/archive/numpy.zip --user --quiet

# %%
# !python train_seg.py --help

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_seg.py \
                            --epochs 1000 \
                            --lr 5e-4 \
                            --data_path ../dataset/Segmentation/separated1/ \
                            --experiment_name case1 \
                            --num_workers 4 \
                            --batch_size 2 \
                            --lossfn boundaryce \
                            --val_batch_size 3 \
                            --net_inputch 3 \
                            --net_outputch 2 \
                            --net_mcdropout 0.1 \
                            --net_norm ws \
                            --net_nnblock True
# Out:
# 2021-05-17 12:33:49,210 - utils - INFO - Entered module: utils
# 2021-05-17 12:33:49,342 - matplotlib - DEBUG - (private) matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# 2021-05-17 12:33:49,344 - matplotlib - DEBUG - matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# 2021-05-17 12:33:49,348 - matplotlib - DEBUG - CONFIGDIR=/home/kevin/.config/matplotlib
# 2021-05-17 12:33:49,353 - matplotlib - DEBUG - matplotlib version 3.3.2
# 2021-05-17 12:33:49,353 - matplotlib - DEBUG - interactive is False
# 2021-05-17 12:33:49,354 - matplotlib - DEBUG - platform is linux
# ...

# %%
lbl.shape

# %%
# !nvidia-smi

# %%
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:  ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /home/kevin/.netrc
# True
