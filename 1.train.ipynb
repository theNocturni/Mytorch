# %% [markdown]
# # Settings

# %%
# gpu status
# !nvidia-smi
import multiprocessing
multiprocessing.cpu_count()
# Out:
# Wed Aug 18 07:45:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           On   | 00000000:1B:00.0 Off |                  N/A |
# | 97%   88C    P2   129W / 280W |  23384MiB / 24220MiB |     75%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN RTX           On   | 00000000:1C:00.0 Off |                  N/A |
# | 40%   57C    P2   281W / 280W |  23906MiB / 24220MiB |     33%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  TITAN RTX           On   | 00000000:1D:00.0 Off |                  N/A |
# |100%   88C    P2   181W / 280W |  21998MiB / 24220MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  TITAN RTX           On   | 00000000:1E:00.0 Off |                  N/A |
# | 40%   50C    P8     9W / 280W |      3MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  TITAN RTX           On   | 00000000:3D:00.0 Off |                  N/A |
# | 41%   28C    P8    16W / 280W |   4985MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  TITAN RTX           On   | 00000000:3F:00.0 Off |                  N/A |
# | 41%   57C    P2    68W / 280W |   5170MiB / 24220MiB |     13%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  TITAN RTX           On   | 00000000:40:00.0 Off |                  N/A |
# | 41%   29C    P8     4W / 280W |  17021MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  TITAN RTX           On   | 00000000:41:00.0 Off |                  N/A |
# | 41%   32C    P8    13W / 280W |  16409MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# 40

# %%
# install packages
# !pip install -r requirements.txt --user --upgrade #--quiet -U
# !apt updates

# %%
# !sudo rm -r logs

# %%
# !ls logs/Retina

# %%
# log into weight and bias, if error occurs, please reset your jupyter kernal
# !sudo pip install wandb --upgrade --user
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: keewonshin (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# # Train

# %%
# run training
# !CUDA_VISIBLE_DEVICES=5 python train.py --project Retina \
                                        --data_dir ../Retina/dataset/DRIVE \
                                        --data_module dataset \
                                        --net waveletunet_r2 \
                                        --net_inputch 3 \
                                        --net_outputch 2 \
                                        --net_norm batch \
                                        --net_nnblock True \
                                        --net_supervision True \
                                        --net_ckpt logs/Retina/3ait2iy2 \
                                        --lossfn skel_FocalLoss \
                                        --precision 16 \
                                        --data_patchsize 128_128 \
                                        --batch_size 24 \
                                        --lr 1e-3
# Out:
# args: Namespace(batch_size=24, data_cropsize=None, data_dir='../Retina/dataset/DRIVE', data_module='dataset', data_padsize=None, data_patchsize='128_128', data_resize=None, experiment_name=None, lossfn='skel_FocalLoss', lr=0.001, net='waveletunet_r2', net_activation='relu', net_ckpt='logs/Retina/3ait2iy2', net_inputch=3, net_nnblock=True, net_norm='batch', net_outputch=2, net_supervision=True, precision=16, project='Retina')
#
# logs/Retina/3ait2iy2/checkpoints/epoch=0236-loss_val=0.0628-metric_val=0.9532.ckpt is loaded
# project Retina
# Current Experiment: DatasetDRIVE_Netwaveletunet_r2_Netnormbatch_Netinputch3_Netoutputch2_Lossskel_FocalLoss_Lr0.001_Precision16_Patchsize128_128_PrefixNone_
#  ****************************************************************************************************
# wandb: Currently logged in as: keewonshin (use `wandb login --relogin` to force relogin)
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.12.0
# wandb: Syncing run DatasetDRIVE_Netwaveletunet_r2_Netnormbatch_Netinputch3_Netoutputch2_Lossskel_FocalLoss_Lr0.001_Precision16_Patchsize128_128_PrefixNone_
# wandb:  View project at https://wandb.ai/keewonshin/Retina
# wandb:  View run at https://wandb.ai/keewonshin/Retina/runs/zo6rti8p
# wandb: Run data is saved locally in logs/wandb/run-20210818_074619-zo6rti8p
# wandb: Run `wandb offline` to turn off syncing.
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# total counts of dataset x 18, y 18
# total counts of dataset x 2, y 2
# total counts of dataset x 20, y 20
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [5]
#
#   | Name   | Type           | Params
# ------------------------------------------
# 0 | lossfn | skel_FocalLoss | 0
# 1 | net    | waveletunet_r2 | 57.1 M
# 2 | metric | F1             | 0
# ------------------------------------------
# 57.1 M    Trainable params
# 0         Non-trainable params
# 57.1 M    Total params
# 228.474   Total estimated model params size (MB)
# Epoch 0:  50%|▌| 1/2 [00:08<00:08,  8.14s/it, loss=1.64, v_num=ti8p, loss_val=1./home/kevin/.local/lib/python3.8/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
#
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█| 2/2 [00:21<00:00, 10.70s/it, loss=1.640, v_num=ti8p, loss_val=1
#                                                                                 Epoch 0, global step 0: metric_val reached 0.91817 (best 0.91817), saving model to "logs/Retina/zo6rti8p/checkpoints/epoch=0000-loss_val=1.5639-metric_val=0.9182.ckpt" as top 3
# Epoch 1:  50%|▌| 1/2 [00:07<00:07,  7.00s/it, loss=1.640, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 2/2 [00:20<00:00, 10.17s/it, loss=1.680, v_num=ti8p, loss_val=1
#                                                                                 Epoch 1, global step 1: metric_val reached 0.91817 (best 0.91817), saving model to "logs/Retina/zo6rti8p/checkpoints/epoch=0001-loss_val=1.5772-metric_val=0.9182.ckpt" as top 3
# Epoch 2:  50%|▌| 1/2 [00:06<00:06,  6.64s/it, loss=1.680, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 2/2 [00:19<00:00,  9.89s/it, loss=1.570, v_num=ti8p, loss_val=1
#                                                                                 Epoch 2, global step 2: metric_val reached 0.91817 (best 0.91817), saving model to "logs/Retina/zo6rti8p/checkpoints/epoch=0002-loss_val=1.5564-metric_val=0.9182.ckpt" as top 3
# Epoch 3:  50%|▌| 1/2 [00:08<00:08,  8.08s/it, loss=1.570, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 2/2 [00:19<00:00,  9.71s/it, loss=1.460, v_num=ti8p, loss_val=1
#                                                                                 Epoch 3, global step 3: metric_val was not in top 3
# Epoch 4:  50%|▌| 1/2 [00:08<00:08,  8.27s/it, loss=1.460, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 2/2 [00:21<00:00, 10.68s/it, loss=1.410, v_num=ti8p, loss_val=1
#                                                                                 Epoch 4, global step 4: metric_val was not in top 3
# Epoch 5:  50%|▌| 1/2 [00:07<00:07,  7.06s/it, loss=1.410, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 2/2 [00:19<00:00,  9.79s/it, loss=1.360, v_num=ti8p, loss_val=1
#                                                                                 Epoch 5, global step 5: metric_val was not in top 3
# Epoch 6:  50%|▌| 1/2 [00:06<00:06,  6.02s/it, loss=1.360, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 2/2 [00:19<00:00,  9.56s/it, loss=1.310, v_num=ti8p, loss_val=1
#                                                                                 Epoch 6, global step 6: metric_val was not in top 3
# Epoch 7:  50%|▌| 1/2 [00:06<00:06,  6.17s/it, loss=1.310, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 2/2 [00:19<00:00,  9.94s/it, loss=1.050, v_num=ti8p, loss_val=1
#                                                                                 Epoch 7, global step 7: metric_val reached 0.91825 (best 0.91825), saving model to "logs/Retina/zo6rti8p/checkpoints/epoch=0007-loss_val=1.4958-metric_val=0.9182.ckpt" as top 3
# Epoch 8:  50%|▌| 1/2 [00:07<00:07,  7.27s/it, loss=1.050, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 2/2 [00:20<00:00, 10.11s/it, loss=0.986, v_num=ti8p, loss_val=1
#                                                                                 Epoch 8, global step 8: metric_val was not in top 3
# Epoch 9:  50%|▌| 1/2 [00:12<00:12, 12.55s/it, loss=0.986, v_num=ti8p, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 2/2 [00:24<00:00, 12.44s/it, loss=0.975, v_num=ti8p, loss_val=1
#                                                                                 Epoch 9, global step 9: metric_val was not in top 3
# Epoch 10:  50%|▌| 1/2 [00:07<00:07,  7.91s/it, loss=0.975, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 2/2 [00:20<00:00, 10.44s/it, loss=0.894, v_num=ti8p, loss_val=
#                                                                                 Epoch 10, global step 10: metric_val was not in top 3
# Epoch 11:  50%|▌| 1/2 [00:07<00:07,  7.38s/it, loss=0.894, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 2/2 [00:20<00:00, 10.21s/it, loss=0.988, v_num=ti8p, loss_val=
#                                                                                 Epoch 11, global step 11: metric_val was not in top 3
# Epoch 12:  50%|▌| 1/2 [00:07<00:07,  7.72s/it, loss=0.988, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 2/2 [00:20<00:00, 10.29s/it, loss=0.886, v_num=ti8p, loss_val=
#                                                                                 Epoch 12, global step 12: metric_val was not in top 3
# Epoch 13:  50%|▌| 1/2 [00:07<00:07,  7.59s/it, loss=0.886, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 2/2 [00:21<00:00, 10.54s/it, loss=nan.0, v_num=ti8p, loss_val=
#                                                                                 Epoch 13, global step 13: metric_val was not in top 3
# Epoch 14:  50%|▌| 1/2 [00:07<00:07,  7.56s/it, loss=nan.0, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 2/2 [00:20<00:00, 10.09s/it, loss=0.934, v_num=ti8p, loss_val=
#                                                                                 Epoch 14, global step 14: metric_val was not in top 3
# Epoch 15:  50%|▌| 1/2 [00:06<00:06,  6.22s/it, loss=0.934, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 2/2 [00:18<00:00,  9.43s/it, loss=0.907, v_num=ti8p, loss_val=
#                                                                                 Epoch 15, global step 15: metric_val was not in top 3
# Epoch 16:  50%|▌| 1/2 [00:08<00:08,  8.04s/it, loss=0.907, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 2/2 [00:20<00:00, 10.02s/it, loss=0.944, v_num=ti8p, loss_val=
#                                                                                 Epoch 16, global step 16: metric_val was not in top 3
# Epoch 17:  50%|▌| 1/2 [00:07<00:07,  7.97s/it, loss=0.944, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 2/2 [00:20<00:00, 10.40s/it, loss=0.912, v_num=ti8p, loss_val=
#                                                                                 Epoch 17, global step 17: metric_val was not in top 3
# Epoch 18:  50%|▌| 1/2 [00:07<00:07,  7.11s/it, loss=0.912, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 2/2 [00:17<00:00,  8.98s/it, loss=0.792, v_num=ti8p, loss_val=
#                                                                                 Epoch 18, global step 18: metric_val was not in top 3
# Epoch 19:  50%|▌| 1/2 [00:10<00:10, 10.64s/it, loss=0.792, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 2/2 [00:24<00:00, 12.08s/it, loss=0.823, v_num=ti8p, loss_val=
#                                                                                 Epoch 19, global step 19: metric_val was not in top 3
# Epoch 20:  50%|▌| 1/2 [00:06<00:06,  6.03s/it, loss=0.823, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 2/2 [00:15<00:00,  7.79s/it, loss=0.821, v_num=ti8p, loss_val=
#                                                                                 Epoch 20, global step 20: metric_val was not in top 3
# Epoch 21:  50%|▌| 1/2 [00:07<00:07,  7.30s/it, loss=0.821, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 2/2 [00:20<00:00, 10.10s/it, loss=0.787, v_num=ti8p, loss_val=
#                                                                                 Epoch 21, global step 21: metric_val was not in top 3
# Epoch 22:  50%|▌| 1/2 [00:07<00:07,  7.99s/it, loss=0.787, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 2/2 [00:19<00:00,  9.52s/it, loss=0.743, v_num=ti8p, loss_val=
#                                                                                 Epoch 22, global step 22: metric_val was not in top 3
# Epoch 23:  50%|▌| 1/2 [00:10<00:10, 10.14s/it, loss=0.743, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|█| 2/2 [00:23<00:00, 11.60s/it, loss=0.977, v_num=ti8p, loss_val=
#                                                                                 Epoch 23, global step 23: metric_val was not in top 3
# Epoch 24:  50%|▌| 1/2 [00:07<00:07,  7.57s/it, loss=0.977, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|█| 2/2 [00:18<00:00,  9.29s/it, loss=0.859, v_num=ti8p, loss_val=
#                                                                                 Epoch 24, global step 24: metric_val was not in top 3
# Epoch 25:  50%|▌| 1/2 [00:06<00:06,  6.14s/it, loss=0.859, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 25: 100%|█| 2/2 [00:18<00:00,  9.48s/it, loss=0.764, v_num=ti8p, loss_val=
#                                                                                 Epoch 25, global step 25: metric_val was not in top 3
# Epoch 26:  50%|▌| 1/2 [00:07<00:07,  7.53s/it, loss=0.764, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 26: 100%|█| 2/2 [00:20<00:00, 10.35s/it, loss=0.751, v_num=ti8p, loss_val=
#                                                                                 Epoch 26, global step 26: metric_val was not in top 3
# Epoch 27:  50%|▌| 1/2 [00:06<00:06,  6.31s/it, loss=0.751, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 27: 100%|█| 2/2 [00:18<00:00,  9.30s/it, loss=0.792, v_num=ti8p, loss_val=
#                                                                                 Epoch 27, global step 27: metric_val was not in top 3
# Epoch 28:  50%|▌| 1/2 [00:07<00:07,  7.53s/it, loss=0.792, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 28: 100%|█| 2/2 [00:20<00:00, 10.22s/it, loss=0.749, v_num=ti8p, loss_val=
#                                                                                 Epoch 28, global step 28: metric_val was not in top 3
# Epoch 29:  50%|▌| 1/2 [00:12<00:12, 12.10s/it, loss=0.749, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 29: 100%|█| 2/2 [00:25<00:00, 12.55s/it, loss=0.740, v_num=ti8p, loss_val=
#                                                                                 Epoch 29, global step 29: metric_val was not in top 3
# Epoch 30:  50%|▌| 1/2 [00:07<00:07,  7.16s/it, loss=0.740, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 30: 100%|█| 2/2 [00:20<00:00, 10.11s/it, loss=0.705, v_num=ti8p, loss_val=
#                                                                                 Epoch 30, global step 30: metric_val was not in top 3
# Epoch 31:  50%|▌| 1/2 [00:05<00:05,  5.20s/it, loss=0.705, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 31: 100%|█| 2/2 [00:16<00:00,  8.27s/it, loss=0.772, v_num=ti8p, loss_val=
#                                                                                 Epoch 31, global step 31: metric_val was not in top 3
# Epoch 32:  50%|▌| 1/2 [00:07<00:07,  7.00s/it, loss=0.772, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 32: 100%|█| 2/2 [00:19<00:00,  9.92s/it, loss=0.654, v_num=ti8p, loss_val=
#                                                                                 Epoch 32, global step 32: metric_val was not in top 3
# Epoch 33:  50%|▌| 1/2 [00:06<00:06,  6.24s/it, loss=0.654, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 33: 100%|█| 2/2 [00:16<00:00,  8.39s/it, loss=0.707, v_num=ti8p, loss_val=
#                                                                                 Epoch 33, global step 33: metric_val was not in top 3
# Epoch 34:  50%|▌| 1/2 [00:06<00:06,  6.97s/it, loss=0.707, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 34: 100%|█| 2/2 [00:20<00:00, 10.34s/it, loss=0.710, v_num=ti8p, loss_val=
#                                                                                 Epoch 34, global step 34: metric_val was not in top 3
# Epoch 35:  50%|▌| 1/2 [00:06<00:06,  6.01s/it, loss=0.710, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 35: 100%|█| 2/2 [00:19<00:00,  9.51s/it, loss=0.716, v_num=ti8p, loss_val=
#                                                                                 Epoch 35, global step 35: metric_val was not in top 3
# Epoch 36:  50%|▌| 1/2 [00:08<00:08,  8.46s/it, loss=0.716, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 36: 100%|█| 2/2 [00:21<00:00, 10.64s/it, loss=0.718, v_num=ti8p, loss_val=
#                                                                                 Epoch 36, global step 36: metric_val was not in top 3
# Epoch 37:  50%|▌| 1/2 [00:06<00:06,  6.08s/it, loss=0.718, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 37: 100%|█| 2/2 [00:19<00:00,  9.65s/it, loss=0.721, v_num=ti8p, loss_val=
#                                                                                 Epoch 37, global step 37: metric_val was not in top 3
# Epoch 38:  50%|▌| 1/2 [00:09<00:09,  9.28s/it, loss=0.721, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 38: 100%|█| 2/2 [00:22<00:00, 11.18s/it, loss=0.711, v_num=ti8p, loss_val=
#                                                                                 Epoch 38, global step 38: metric_val was not in top 3
# Epoch 39:  50%|▌| 1/2 [00:09<00:09,  9.19s/it, loss=0.711, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 39: 100%|█| 2/2 [00:22<00:00, 11.14s/it, loss=0.727, v_num=ti8p, loss_val=
#                                                                                 Epoch 39, global step 39: metric_val was not in top 3
# Epoch 40:  50%|▌| 1/2 [00:05<00:05,  5.73s/it, loss=0.727, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 40: 100%|█| 2/2 [00:17<00:00,  8.74s/it, loss=0.680, v_num=ti8p, loss_val=
#                                                                                 Epoch 40, global step 40: metric_val was not in top 3
# Epoch 41:  50%|▌| 1/2 [00:07<00:07,  7.23s/it, loss=0.680, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 41: 100%|█| 2/2 [00:20<00:00, 10.17s/it, loss=0.704, v_num=ti8p, loss_val=
#                                                                                 Epoch 41, global step 41: metric_val was not in top 3
# Epoch 42:  50%|▌| 1/2 [00:06<00:06,  6.26s/it, loss=0.704, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 42: 100%|█| 2/2 [00:16<00:00,  8.37s/it, loss=0.696, v_num=ti8p, loss_val=
#                                                                                 Epoch 42, global step 42: metric_val was not in top 3
# Epoch 43:  50%|▌| 1/2 [00:04<00:04,  4.82s/it, loss=0.696, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 43: 100%|█| 2/2 [00:18<00:00,  9.21s/it, loss=0.644, v_num=ti8p, loss_val=
#                                                                                 Epoch 43, global step 43: metric_val was not in top 3
# Epoch 44:  50%|▌| 1/2 [00:06<00:06,  6.05s/it, loss=0.644, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 44: 100%|█| 2/2 [00:18<00:00,  9.32s/it, loss=0.671, v_num=ti8p, loss_val=
#                                                                                 Epoch 44, global step 44: metric_val was not in top 3
# Epoch 45:  50%|▌| 1/2 [00:06<00:06,  6.78s/it, loss=0.671, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 45: 100%|█| 2/2 [00:20<00:00, 10.07s/it, loss=0.633, v_num=ti8p, loss_val=
#                                                                                 Epoch 45, global step 45: metric_val was not in top 3
# Epoch 46:  50%|▌| 1/2 [00:05<00:05,  5.91s/it, loss=0.633, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 46: 100%|█| 2/2 [00:18<00:00,  9.49s/it, loss=0.674, v_num=ti8p, loss_val=
#                                                                                 Epoch 46, global step 46: metric_val was not in top 3
# Epoch 47:  50%|▌| 1/2 [00:06<00:06,  6.63s/it, loss=0.674, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 47: 100%|█| 2/2 [00:20<00:00, 10.45s/it, loss=0.656, v_num=ti8p, loss_val=
#                                                                                 Epoch 47, global step 47: metric_val was not in top 3
# Epoch 48:  50%|▌| 1/2 [00:08<00:08,  8.40s/it, loss=0.656, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 48: 100%|█| 2/2 [00:21<00:00, 10.81s/it, loss=0.691, v_num=ti8p, loss_val=
#                                                                                 Epoch 48, global step 48: metric_val was not in top 3
# Epoch 49:  50%|▌| 1/2 [00:10<00:10, 10.55s/it, loss=0.691, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█| 2/2 [00:24<00:00, 12.07s/it, loss=0.695, v_num=ti8p, loss_val=
#                                                                                 Epoch 49, global step 49: metric_val was not in top 3
# Epoch 50:  50%|▌| 1/2 [00:06<00:06,  6.16s/it, loss=0.695, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 50: 100%|█| 2/2 [00:19<00:00,  9.89s/it, loss=0.651, v_num=ti8p, loss_val=
#                                                                                 Epoch 50, global step 50: metric_val was not in top 3
# Epoch 51:  50%|▌| 1/2 [00:08<00:08,  8.32s/it, loss=0.651, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 51: 100%|█| 2/2 [00:21<00:00, 10.68s/it, loss=0.662, v_num=ti8p, loss_val=
#                                                                                 Epoch 51, global step 51: metric_val was not in top 3
# Epoch 52:  50%|▌| 1/2 [00:06<00:06,  6.30s/it, loss=0.662, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 52: 100%|█| 2/2 [00:19<00:00,  9.57s/it, loss=0.667, v_num=ti8p, loss_val=
#                                                                                 Epoch 52, global step 52: metric_val was not in top 3
# Epoch 53:  50%|▌| 1/2 [00:06<00:06,  6.22s/it, loss=0.667, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 53: 100%|█| 2/2 [00:17<00:00,  8.63s/it, loss=0.643, v_num=ti8p, loss_val=
#                                                                                 Epoch 53, global step 53: metric_val was not in top 3
# Epoch 54:  50%|▌| 1/2 [00:07<00:07,  7.66s/it, loss=0.643, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 54: 100%|█| 2/2 [00:21<00:00, 10.83s/it, loss=0.680, v_num=ti8p, loss_val=
#                                                                                 Epoch 54, global step 54: metric_val was not in top 3
# Epoch 55:  50%|▌| 1/2 [00:06<00:06,  6.77s/it, loss=0.680, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 55: 100%|█| 2/2 [00:18<00:00,  9.01s/it, loss=0.676, v_num=ti8p, loss_val=
#                                                                                 Epoch 55, global step 55: metric_val was not in top 3
# Epoch 56:  50%|▌| 1/2 [00:07<00:07,  7.29s/it, loss=0.676, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 56: 100%|█| 2/2 [00:20<00:00, 10.32s/it, loss=0.637, v_num=ti8p, loss_val=
#                                                                                 Epoch 56, global step 56: metric_val was not in top 3
# Epoch 57:  50%|▌| 1/2 [00:08<00:08,  8.46s/it, loss=0.637, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 57: 100%|█| 2/2 [00:19<00:00,  9.96s/it, loss=0.722, v_num=ti8p, loss_val=
#                                                                                 Epoch 57, global step 57: metric_val was not in top 3
# Epoch 58:  50%|▌| 1/2 [00:06<00:06,  6.25s/it, loss=0.722, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 58: 100%|█| 2/2 [00:19<00:00,  9.72s/it, loss=0.603, v_num=ti8p, loss_val=
#                                                                                 Epoch 58, global step 58: metric_val was not in top 3
# Epoch 59:  50%|▌| 1/2 [00:12<00:12, 12.81s/it, loss=0.603, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 59: 100%|█| 2/2 [00:23<00:00, 11.94s/it, loss=0.640, v_num=ti8p, loss_val=
#                                                                                 Epoch 59, global step 59: metric_val was not in top 3
# Epoch 60:  50%|▌| 1/2 [00:06<00:06,  6.44s/it, loss=0.640, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 60: 100%|█| 2/2 [00:19<00:00,  9.79s/it, loss=0.714, v_num=ti8p, loss_val=
#                                                                                 Epoch 60, global step 60: metric_val was not in top 3
# Epoch 61:  50%|▌| 1/2 [00:06<00:06,  6.77s/it, loss=0.714, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 61: 100%|█| 2/2 [00:16<00:00,  8.40s/it, loss=0.594, v_num=ti8p, loss_val=
#                                                                                 Epoch 61, global step 61: metric_val was not in top 3
# Epoch 62:  50%|▌| 1/2 [00:09<00:09,  9.05s/it, loss=0.594, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 62: 100%|█| 2/2 [00:22<00:00, 11.17s/it, loss=0.624, v_num=ti8p, loss_val=
#                                                                                 Epoch 62, global step 62: metric_val was not in top 3
# Epoch 63:  50%|▌| 1/2 [00:09<00:09,  9.09s/it, loss=0.624, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 63: 100%|█| 2/2 [00:20<00:00, 10.42s/it, loss=0.744, v_num=ti8p, loss_val=
#                                                                                 Epoch 63, global step 63: metric_val was not in top 3
# Epoch 64:  50%|▌| 1/2 [00:06<00:06,  6.18s/it, loss=0.744, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 64: 100%|█| 2/2 [00:19<00:00,  9.53s/it, loss=0.655, v_num=ti8p, loss_val=
#                                                                                 Epoch 64, global step 64: metric_val was not in top 3
# Epoch 65:  50%|▌| 1/2 [00:06<00:06,  6.87s/it, loss=0.655, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 65: 100%|█| 2/2 [00:18<00:00,  9.23s/it, loss=0.778, v_num=ti8p, loss_val=
#                                                                                 Epoch 65, global step 65: metric_val was not in top 3
# Epoch 66:  50%|▌| 1/2 [00:07<00:07,  7.02s/it, loss=0.778, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 66: 100%|█| 2/2 [00:19<00:00,  9.98s/it, loss=0.632, v_num=ti8p, loss_val=
#                                                                                 Epoch 66, global step 66: metric_val was not in top 3
# Epoch 67:  50%|▌| 1/2 [00:08<00:08,  8.90s/it, loss=0.632, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 67: 100%|█| 2/2 [00:21<00:00, 10.88s/it, loss=0.606, v_num=ti8p, loss_val=
#                                                                                 Epoch 67, global step 67: metric_val was not in top 3
# Epoch 68:  50%|▌| 1/2 [00:08<00:08,  8.32s/it, loss=0.606, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 68: 100%|█| 2/2 [00:21<00:00, 10.84s/it, loss=0.667, v_num=ti8p, loss_val=
#                                                                                 Epoch 68, global step 68: metric_val was not in top 3
# Epoch 69:  50%|▌| 1/2 [00:11<00:11, 11.02s/it, loss=0.667, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 69: 100%|█| 2/2 [00:22<00:00, 11.40s/it, loss=0.702, v_num=ti8p, loss_val=
#                                                                                 Epoch 69, global step 69: metric_val was not in top 3
# Epoch 70:  50%|▌| 1/2 [00:04<00:04,  4.85s/it, loss=0.702, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 70: 100%|█| 2/2 [00:14<00:00,  7.22s/it, loss=0.683, v_num=ti8p, loss_val=
#                                                                                 Epoch 70, global step 70: metric_val was not in top 3
# Epoch 71:  50%|▌| 1/2 [00:05<00:05,  5.77s/it, loss=0.683, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 71: 100%|█| 2/2 [00:15<00:00,  7.57s/it, loss=0.704, v_num=ti8p, loss_val=
#                                                                                 Epoch 71, global step 71: metric_val was not in top 3
# Epoch 72:  50%|▌| 1/2 [00:07<00:07,  7.05s/it, loss=0.704, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 72: 100%|█| 2/2 [00:15<00:00,  7.99s/it, loss=0.598, v_num=ti8p, loss_val=
#                                                                                 Epoch 72, global step 72: metric_val was not in top 3
# Epoch 73:  50%|▌| 1/2 [00:05<00:05,  5.87s/it, loss=0.598, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 73: 100%|█| 2/2 [00:14<00:00,  7.35s/it, loss=0.622, v_num=ti8p, loss_val=
#                                                                                 Epoch 73, global step 73: metric_val was not in top 3
# Epoch 74:  50%|▌| 1/2 [00:05<00:05,  5.56s/it, loss=0.622, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 74: 100%|█| 2/2 [00:15<00:00,  7.61s/it, loss=0.725, v_num=ti8p, loss_val=
#                                                                                 Epoch 74, global step 74: metric_val was not in top 3
# Epoch 75:  50%|▌| 1/2 [00:05<00:05,  5.92s/it, loss=0.725, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 75: 100%|█| 2/2 [00:15<00:00,  7.68s/it, loss=0.641, v_num=ti8p, loss_val=
#                                                                                 Epoch 75, global step 75: metric_val was not in top 3
# Epoch 76:  50%|▌| 1/2 [00:07<00:07,  7.30s/it, loss=0.641, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 76: 100%|█| 2/2 [00:16<00:00,  8.19s/it, loss=0.684, v_num=ti8p, loss_val=
#                                                                                 Epoch 76, global step 76: metric_val was not in top 3
# Epoch 77:  50%|▌| 1/2 [00:05<00:05,  5.83s/it, loss=0.684, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 77: 100%|█| 2/2 [00:15<00:00,  7.60s/it, loss=0.582, v_num=ti8p, loss_val=
#                                                                                 Epoch 77, global step 77: metric_val was not in top 3
# Epoch 78:  50%|▌| 1/2 [00:06<00:06,  6.51s/it, loss=0.582, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 78: 100%|█| 2/2 [00:15<00:00,  7.71s/it, loss=0.640, v_num=ti8p, loss_val=
#                                                                                 Epoch 78, global step 78: metric_val was not in top 3
# Epoch 79:  50%|▌| 1/2 [00:09<00:09,  9.42s/it, loss=0.640, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 79: 100%|█| 2/2 [00:18<00:00,  9.16s/it, loss=0.587, v_num=ti8p, loss_val=
#                                                                                 Epoch 79, global step 79: metric_val was not in top 3
# Epoch 80:  50%|▌| 1/2 [00:05<00:05,  5.66s/it, loss=0.587, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 80: 100%|█| 2/2 [00:14<00:00,  7.29s/it, loss=0.645, v_num=ti8p, loss_val=
#                                                                                 Epoch 80, global step 80: metric_val was not in top 3
# Epoch 81:  50%|▌| 1/2 [00:06<00:06,  6.27s/it, loss=0.645, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 81: 100%|█| 2/2 [00:15<00:00,  7.62s/it, loss=0.659, v_num=ti8p, loss_val=
#                                                                                 Epoch 81, global step 81: metric_val was not in top 3
# Epoch 82:  50%|▌| 1/2 [00:05<00:05,  5.20s/it, loss=0.659, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 82: 100%|█| 2/2 [00:14<00:00,  7.05s/it, loss=0.598, v_num=ti8p, loss_val=
#                                                                                 Epoch 82, global step 82: metric_val was not in top 3
# Epoch 83:  50%|▌| 1/2 [00:06<00:06,  6.32s/it, loss=0.598, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 83: 100%|█| 2/2 [00:15<00:00,  7.77s/it, loss=0.590, v_num=ti8p, loss_val=
#                                                                                 Epoch 83, global step 83: metric_val was not in top 3
# Epoch 84:  50%|▌| 1/2 [00:05<00:05,  5.42s/it, loss=0.590, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 84: 100%|█| 2/2 [00:14<00:00,  7.34s/it, loss=0.618, v_num=ti8p, loss_val=
#                                                                                 Epoch 84, global step 84: metric_val was not in top 3
# Epoch 85:  50%|▌| 1/2 [00:05<00:05,  5.58s/it, loss=0.618, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 85: 100%|█| 2/2 [00:14<00:00,  7.49s/it, loss=0.595, v_num=ti8p, loss_val=
#                                                                                 Epoch 85, global step 85: metric_val was not in top 3
# Epoch 86:  50%|▌| 1/2 [00:05<00:05,  5.43s/it, loss=0.595, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 86: 100%|█| 2/2 [00:14<00:00,  7.31s/it, loss=0.611, v_num=ti8p, loss_val=
#                                                                                 Epoch 86, global step 86: metric_val was not in top 3
# Epoch 87:  50%|▌| 1/2 [00:06<00:06,  6.40s/it, loss=0.611, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 87: 100%|█| 2/2 [00:15<00:00,  7.73s/it, loss=0.695, v_num=ti8p, loss_val=
#                                                                                 Epoch 87, global step 87: metric_val was not in top 3
# Epoch 88:  50%|▌| 1/2 [00:05<00:05,  5.65s/it, loss=0.695, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 88: 100%|█| 2/2 [00:14<00:00,  7.21s/it, loss=0.644, v_num=ti8p, loss_val=
#                                                                                 Epoch 88, global step 88: metric_val was not in top 3
# Epoch 89:  50%|▌| 1/2 [00:08<00:08,  8.57s/it, loss=0.644, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 89: 100%|█| 2/2 [00:17<00:00,  8.75s/it, loss=0.579, v_num=ti8p, loss_val=
#                                                                                 Epoch 89, global step 89: metric_val was not in top 3
# Epoch 90:  50%|▌| 1/2 [00:06<00:06,  6.94s/it, loss=0.579, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 90: 100%|█| 2/2 [00:16<00:00,  8.08s/it, loss=nan.0, v_num=ti8p, loss_val=
#                                                                                 Epoch 90, global step 90: metric_val was not in top 3
# Epoch 91:  50%|▌| 1/2 [00:06<00:06,  6.32s/it, loss=nan.0, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 91: 100%|█| 2/2 [00:15<00:00,  7.85s/it, loss=0.633, v_num=ti8p, loss_val=
#                                                                                 Epoch 91, global step 91: metric_val was not in top 3
# Epoch 92:  50%|▌| 1/2 [00:09<00:09,  9.20s/it, loss=0.633, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 92: 100%|█| 2/2 [00:18<00:00,  9.18s/it, loss=0.576, v_num=ti8p, loss_val=
#                                                                                 Epoch 92, global step 92: metric_val was not in top 3
# Epoch 93:  50%|▌| 1/2 [00:05<00:05,  5.77s/it, loss=0.576, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 93: 100%|█| 2/2 [00:14<00:00,  7.34s/it, loss=0.599, v_num=ti8p, loss_val=
#                                                                                 Epoch 93, global step 93: metric_val was not in top 3
# Epoch 94:  50%|▌| 1/2 [00:06<00:06,  6.54s/it, loss=0.599, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 94: 100%|█| 2/2 [00:15<00:00,  7.90s/it, loss=0.654, v_num=ti8p, loss_val=
#                                                                                 Epoch 94, global step 94: metric_val was not in top 3
# Epoch 95:  50%|▌| 1/2 [00:06<00:06,  6.39s/it, loss=0.654, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 95: 100%|█| 2/2 [00:14<00:00,  7.44s/it, loss=0.547, v_num=ti8p, loss_val=
#                                                                                 Epoch 95, global step 95: metric_val was not in top 3
# Epoch 96:  50%|▌| 1/2 [00:07<00:07,  7.27s/it, loss=0.547, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 96: 100%|█| 2/2 [00:16<00:00,  8.10s/it, loss=0.657, v_num=ti8p, loss_val=
#                                                                                 Epoch 96, global step 96: metric_val was not in top 3
# Epoch 97:  50%|▌| 1/2 [00:05<00:05,  5.65s/it, loss=0.657, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 97: 100%|█| 2/2 [00:14<00:00,  7.41s/it, loss=0.663, v_num=ti8p, loss_val=
#                                                                                 Epoch 97, global step 97: metric_val was not in top 3
# Epoch 98:  50%|▌| 1/2 [00:05<00:05,  5.56s/it, loss=0.663, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 98: 100%|█| 2/2 [00:14<00:00,  7.18s/it, loss=0.588, v_num=ti8p, loss_val=
#                                                                                 Epoch 98, global step 98: metric_val was not in top 3
# Epoch 99:  50%|▌| 1/2 [00:07<00:07,  7.80s/it, loss=0.588, v_num=ti8p, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 99: 100%|█| 2/2 [00:16<00:00,  8.48s/it, loss=0.589, v_num=ti8p, loss_val=
#                                                                                 Epoch 99, global step 99: metric_val was not in top 3
# Epoch 100:  50%|▌| 1/2 [00:06<00:06,  6.97s/it, loss=0.589, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 100: 100%|█| 2/2 [00:16<00:00,  8.01s/it, loss=0.624, v_num=ti8p, loss_val
#                                                                                 Epoch 100, global step 100: metric_val was not in top 3
# Epoch 101:  50%|▌| 1/2 [00:06<00:06,  6.95s/it, loss=0.624, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 101: 100%|█| 2/2 [00:15<00:00,  7.86s/it, loss=0.629, v_num=ti8p, loss_val
#                                                                                 Epoch 101, global step 101: metric_val was not in top 3
# Epoch 102:  50%|▌| 1/2 [00:07<00:07,  7.60s/it, loss=0.629, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 102: 100%|█| 2/2 [00:16<00:00,  8.39s/it, loss=0.629, v_num=ti8p, loss_val
#                                                                                 Epoch 102, global step 102: metric_val was not in top 3
# Epoch 103:  50%|▌| 1/2 [00:07<00:07,  7.05s/it, loss=0.629, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 103: 100%|█| 2/2 [00:15<00:00,  7.77s/it, loss=0.633, v_num=ti8p, loss_val
#                                                                                 Epoch 103, global step 103: metric_val was not in top 3
# Epoch 104:  50%|▌| 1/2 [00:07<00:07,  7.34s/it, loss=0.633, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 104: 100%|█| 2/2 [00:16<00:00,  8.16s/it, loss=0.693, v_num=ti8p, loss_val
#                                                                                 Epoch 104, global step 104: metric_val was not in top 3
# Epoch 105:  50%|▌| 1/2 [00:06<00:06,  6.62s/it, loss=0.693, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 105: 100%|█| 2/2 [00:16<00:00,  8.23s/it, loss=0.626, v_num=ti8p, loss_val
#                                                                                 Epoch 105, global step 105: metric_val was not in top 3
# Epoch 106:  50%|▌| 1/2 [00:06<00:06,  6.53s/it, loss=0.626, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 106: 100%|█| 2/2 [00:15<00:00,  7.75s/it, loss=0.611, v_num=ti8p, loss_val
#                                                                                 Epoch 106, global step 106: metric_val was not in top 3
# Epoch 107:  50%|▌| 1/2 [00:05<00:05,  5.53s/it, loss=0.611, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 107: 100%|█| 2/2 [00:14<00:00,  7.26s/it, loss=0.558, v_num=ti8p, loss_val
#                                                                                 Epoch 107, global step 107: metric_val was not in top 3
# Epoch 108:  50%|▌| 1/2 [00:06<00:06,  6.95s/it, loss=0.558, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 108: 100%|█| 2/2 [00:15<00:00,  7.96s/it, loss=0.632, v_num=ti8p, loss_val
#                                                                                 Epoch 108, global step 108: metric_val was not in top 3
# Epoch 109:  50%|▌| 1/2 [00:08<00:08,  8.31s/it, loss=0.632, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 109: 100%|█| 2/2 [00:17<00:00,  8.59s/it, loss=0.672, v_num=ti8p, loss_val
#                                                                                 Epoch 109, global step 109: metric_val was not in top 3
# Epoch 110:  50%|▌| 1/2 [00:05<00:05,  5.75s/it, loss=0.672, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# ...
#                                                                                 Epoch 274, global step 274: metric_val was not in top 3
# Epoch 275:  50%|▌| 1/2 [00:06<00:06,  6.06s/it, loss=0.611, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 275: 100%|█| 2/2 [00:15<00:00,  7.72s/it, loss=0.556, v_num=ti8p, loss_val
#                                                                                 Epoch 275, global step 275: metric_val was not in top 3
# Epoch 276:  50%|▌| 1/2 [00:04<00:04,  4.96s/it, loss=0.556, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 276: 100%|█| 2/2 [00:13<00:00,  6.99s/it, loss=0.526, v_num=ti8p, loss_val
#                                                                                 Epoch 276, global step 276: metric_val was not in top 3
# Epoch 277:  50%|▌| 1/2 [00:07<00:07,  7.07s/it, loss=0.526, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 277: 100%|█| 2/2 [00:16<00:00,  8.32s/it, loss=0.605, v_num=ti8p, loss_val
#                                                                                 Epoch 277, global step 277: metric_val was not in top 3
# Epoch 278:  50%|▌| 1/2 [00:05<00:05,  5.69s/it, loss=0.605, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 278: 100%|█| 2/2 [00:14<00:00,  7.33s/it, loss=0.580, v_num=ti8p, loss_val
#                                                                                 Epoch 278, global step 278: metric_val was not in top 3
# Epoch 279:  50%|▌| 1/2 [00:11<00:11, 11.01s/it, loss=0.580, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 279: 100%|█| 2/2 [00:19<00:00,  9.95s/it, loss=0.570, v_num=ti8p, loss_val
#                                                                                 Epoch 279, global step 279: metric_val was not in top 3
# Epoch 280:  50%|▌| 1/2 [00:06<00:06,  6.31s/it, loss=0.570, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 280: 100%|█| 2/2 [00:15<00:00,  7.59s/it, loss=0.516, v_num=ti8p, loss_val
#                                                                                 Epoch 280, global step 280: metric_val was not in top 3
# Epoch 281:  50%|▌| 1/2 [00:06<00:06,  6.25s/it, loss=0.516, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 281: 100%|█| 2/2 [00:15<00:00,  7.98s/it, loss=0.549, v_num=ti8p, loss_val
#                                                                                 Epoch 281, global step 281: metric_val was not in top 3
# Epoch 282:  50%|▌| 1/2 [00:05<00:05,  5.65s/it, loss=0.549, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 282: 100%|█| 2/2 [00:14<00:00,  7.48s/it, loss=0.537, v_num=ti8p, loss_val
#                                                                                 Epoch 282, global step 282: metric_val was not in top 3
# Epoch 283:  50%|▌| 1/2 [00:08<00:08,  8.19s/it, loss=0.537, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 283: 100%|█| 2/2 [00:17<00:00,  8.64s/it, loss=0.570, v_num=ti8p, loss_val
#                                                                                 Epoch 283, global step 283: metric_val was not in top 3
# Epoch 284:  50%|▌| 1/2 [00:05<00:05,  5.82s/it, loss=0.570, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 284: 100%|█| 2/2 [00:15<00:00,  7.59s/it, loss=0.519, v_num=ti8p, loss_val
#                                                                                 Epoch 284, global step 284: metric_val was not in top 3
# Epoch 285:  50%|▌| 1/2 [00:06<00:06,  7.00s/it, loss=0.519, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 285: 100%|█| 2/2 [00:15<00:00,  7.98s/it, loss=nan.0, v_num=ti8p, loss_val
#                                                                                 Epoch 285, global step 285: metric_val was not in top 3
# Epoch 286:  50%|▌| 1/2 [00:12<00:12, 12.80s/it, loss=nan.0, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 286: 100%|█| 2/2 [00:22<00:00, 11.01s/it, loss=0.595, v_num=ti8p, loss_val
#                                                                                 Epoch 286, global step 286: metric_val was not in top 3
# Epoch 287:  50%|▌| 1/2 [00:07<00:07,  7.20s/it, loss=0.595, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 287: 100%|█| 2/2 [00:16<00:00,  8.19s/it, loss=0.514, v_num=ti8p, loss_val
#                                                                                 Epoch 287, global step 287: metric_val was not in top 3
# Epoch 288:  50%|▌| 1/2 [00:08<00:08,  8.81s/it, loss=0.514, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 288: 100%|█| 2/2 [00:18<00:00,  9.02s/it, loss=0.550, v_num=ti8p, loss_val
#                                                                                 Epoch 288, global step 288: metric_val was not in top 3
# Epoch 289:  50%|▌| 1/2 [00:08<00:08,  8.78s/it, loss=0.550, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 289: 100%|█| 2/2 [00:17<00:00,  8.91s/it, loss=0.629, v_num=ti8p, loss_val
#                                                                                 Epoch 289, global step 289: metric_val was not in top 3
# Epoch 290:  50%|▌| 1/2 [00:05<00:05,  5.61s/it, loss=0.629, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 290: 100%|█| 2/2 [00:14<00:00,  7.49s/it, loss=0.527, v_num=ti8p, loss_val
#                                                                                 Epoch 290, global step 290: metric_val was not in top 3
# Epoch 291:  50%|▌| 1/2 [00:07<00:07,  7.46s/it, loss=0.527, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 291: 100%|█| 2/2 [00:16<00:00,  8.34s/it, loss=0.564, v_num=ti8p, loss_val
#                                                                                 Epoch 291, global step 291: metric_val was not in top 3
# Epoch 292:  50%|▌| 1/2 [00:07<00:07,  7.45s/it, loss=0.564, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 292: 100%|█| 2/2 [00:16<00:00,  8.41s/it, loss=0.524, v_num=ti8p, loss_val
#                                                                                 Epoch 292, global step 292: metric_val was not in top 3
# Epoch 293:  50%|▌| 1/2 [00:08<00:08,  8.31s/it, loss=0.524, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 293: 100%|█| 2/2 [00:17<00:00,  8.76s/it, loss=0.609, v_num=ti8p, loss_val
#                                                                                 Epoch 293, global step 293: metric_val was not in top 3
# Epoch 294:  50%|▌| 1/2 [00:04<00:04,  4.96s/it, loss=0.609, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 294: 100%|█| 2/2 [00:14<00:00,  7.09s/it, loss=0.554, v_num=ti8p, loss_val
#                                                                                 Epoch 294, global step 294: metric_val was not in top 3
# Epoch 295:  50%|▌| 1/2 [00:07<00:07,  7.33s/it, loss=0.554, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 295: 100%|█| 2/2 [00:16<00:00,  8.25s/it, loss=0.593, v_num=ti8p, loss_val
#                                                                                 Epoch 295, global step 295: metric_val was not in top 3
# Epoch 296:  50%|▌| 1/2 [00:06<00:06,  6.39s/it, loss=0.593, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 296: 100%|█| 2/2 [00:15<00:00,  7.69s/it, loss=0.518, v_num=ti8p, loss_val
#                                                                                 Epoch 296, global step 296: metric_val was not in top 3
# Epoch 297:  50%|▌| 1/2 [00:06<00:06,  6.13s/it, loss=0.518, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 297: 100%|█| 2/2 [00:15<00:00,  7.69s/it, loss=0.508, v_num=ti8p, loss_val
#                                                                                 Epoch 297, global step 297: metric_val was not in top 3
# Epoch 298:  50%|▌| 1/2 [00:06<00:06,  6.82s/it, loss=0.508, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 298: 100%|█| 2/2 [00:16<00:00,  8.11s/it, loss=0.633, v_num=ti8p, loss_val
#                                                                                 Epoch 298, global step 298: metric_val was not in top 3
# Epoch 299:  50%|▌| 1/2 [00:09<00:09,  9.68s/it, loss=0.633, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 299: 100%|█| 2/2 [00:18<00:00,  9.44s/it, loss=0.557, v_num=ti8p, loss_val
#                                                                                 Epoch 299, global step 299: metric_val was not in top 3
# Epoch 300:  50%|▌| 1/2 [00:09<00:09,  9.69s/it, loss=0.557, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 300: 100%|█| 2/2 [00:18<00:00,  9.29s/it, loss=0.519, v_num=ti8p, loss_val
#                                                                                 Epoch 300, global step 300: metric_val was not in top 3
# Epoch 301:  50%|▌| 1/2 [00:05<00:05,  5.01s/it, loss=0.519, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 301: 100%|█| 2/2 [00:14<00:00,  7.12s/it, loss=0.599, v_num=ti8p, loss_val
#                                                                                 Epoch 301, global step 301: metric_val was not in top 3
# Epoch 302:  50%|▌| 1/2 [00:06<00:06,  6.63s/it, loss=0.599, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 302: 100%|█| 2/2 [00:16<00:00,  8.10s/it, loss=0.591, v_num=ti8p, loss_val
#                                                                                 Epoch 302, global step 302: metric_val was not in top 3
# Epoch 303:  50%|▌| 1/2 [00:08<00:08,  8.18s/it, loss=0.591, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 303: 100%|█| 2/2 [00:17<00:00,  8.81s/it, loss=0.560, v_num=ti8p, loss_val
#                                                                                 Epoch 303, global step 303: metric_val was not in top 3
# Epoch 304:  50%|▌| 1/2 [00:08<00:08,  8.27s/it, loss=0.560, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 304: 100%|█| 2/2 [00:17<00:00,  8.66s/it, loss=0.534, v_num=ti8p, loss_val
#                                                                                 Epoch 304, global step 304: metric_val was not in top 3
# Epoch 305:  50%|▌| 1/2 [00:07<00:07,  7.03s/it, loss=0.534, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 305: 100%|█| 2/2 [00:16<00:00,  8.41s/it, loss=0.536, v_num=ti8p, loss_val
#                                                                                 Epoch 305, global step 305: metric_val was not in top 3
# Epoch 306:  50%|▌| 1/2 [00:05<00:05,  5.67s/it, loss=0.536, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 306: 100%|█| 2/2 [00:14<00:00,  7.37s/it, loss=0.540, v_num=ti8p, loss_val
#                                                                                 Epoch 306, global step 306: metric_val was not in top 3
# Epoch 307:  50%|▌| 1/2 [00:08<00:08,  8.24s/it, loss=0.540, v_num=ti8p, loss_val
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 307: 100%|█| 2/2 [00:16<00:00,  8.47s/it, loss=0.564, v_num=ti8p, loss_val
#                                                                                 Epoch 307, global step 307: metric_val was not in top 3
# Epoch 307: 100%|█| 2/2 [00:16<00:00,  8.47s/it, loss=0.564, v_num=ti8p, loss_val
# wandb: WARNING Symlinked 0 file into the W&B run directory, call wandb.save again to sync new files.
#
# wandb: Waiting for W&B process to finish, PID 21382
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: logs/wandb/run-20210818_074619-zo6rti8p/logs/debug.log
# wandb: Find internal logs for this run at: logs/wandb/run-20210818_074619-zo6rti8p/logs/debug-internal.log
# wandb: Run summary:
# wandb:                                                 _runtime 5238
# wandb:                                               _timestamp 1629245618
# wandb:                                                    _step 1540
# wandb:                                                  lr-Adam 4e-05
# wandb:                                      trainer/global_step 307
# wandb:                                                     loss 0.56378
# wandb:                                                   metric 0.94564
# wandb:                                                    epoch 307
# wandb:                                                 loss_val nan
# wandb:                                               metric_val 0.91817
# wandb: Run history:
# wandb:              _runtime ▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            _timestamp ▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 _step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:               lr-Adam █████▇▇▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:   trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                  loss █▅▄▄▃▂▂▂▃▂▁▂▁▂▂▂▁▂▁▁▁▁▂▂▁▁▁▁▂▂▁▁▁▁▂▁▁▁▁▁
# wandb:                metric ▁▄▆▇▆▇▇▇█▇▇▇▇▇▇▇▇█▇█▇█▇▇█▇▇▇▇▇████▇█▇▇█▇
# wandb:                 epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:              loss_val █▁
# wandb:            metric_val ▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Synced 6 W&B file(s), 1851 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced DatasetDRIVE_Netwaveletunet_r2_Netnormbatch_Netinputch3_Netoutputch2_Lossskel_FocalLoss_Lr0.001_Precision16_Patchsize128_128_PrefixNone_: https://wandb.ai/keewonshin/Retina/runs/zo6rti8p

# %% [markdown]
# # Sweeps

# %%
# generate sweep using sweep.yaml
# !python -m wandb sweep sweep.yaml

# %%
# Run sweeps
# !CUDA_VISIBLE_DEVICES=0 python -m wandb agent [your_sweep_address]
# !CUDA_VISIBLE_DEVICES=6 python -m wandb agent keewonshin/Retina/yy8sgak3
