# %% [markdown]
# # Settings

# %%
# gpu status
# !nvidia-smi
import multiprocessing
multiprocessing.cpu_count()
# Out:
# Mon Aug 30 08:46:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           On   | 00000000:1B:00.0 Off |                  N/A |
# | 65%   83C    P2   119W / 280W |  23384MiB / 24220MiB |     72%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN RTX           On   | 00000000:1C:00.0 Off |                  N/A |
# | 40%   56C    P2   279W / 280W |  23382MiB / 24220MiB |     32%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  TITAN RTX           On   | 00000000:1D:00.0 Off |                  N/A |
# | 41%   45C    P8    11W / 280W |   8812MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  TITAN RTX           On   | 00000000:1E:00.0 Off |                  N/A |
# | 41%   43C    P8     8W / 280W |    166MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  TITAN RTX           On   | 00000000:3D:00.0 Off |                  N/A |
# | 41%   32C    P8    16W / 280W |   7790MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  TITAN RTX           On   | 00000000:3F:00.0 Off |                  N/A |
# | 40%   40C    P8     6W / 280W |      3MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  TITAN RTX           On   | 00000000:40:00.0 Off |                  N/A |
# | 98%   88C    P2   163W / 280W |  13893MiB / 24220MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  TITAN RTX           On   | 00000000:41:00.0 Off |                  N/A |
# | 54%   69C    P8    16W / 280W |      3MiB / 24220MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# 40

# %%
# install packages
# !pip install -r requirements.txt --user --upgrade #--quiet -U
# !apt updates

# %%
# !sudo rm -r logs

# %%
# !ls logs/Retina

# %%
# log into weight and bias, if error occurs, please reset your jupyter kernal
# !sudo pip install wandb --upgrade --user
import wandb
wandb.login()

# %% [markdown]
# # Train

# %%
# !free -m

# %%
# run training
# !CUDA_VISIBLE_DEVICES=7 python3 train.py --project RetinaV3 \
                                        --data_dir DRIVE \
                                        --data_module dataset \
                                        --net waveletunet_att \
                                        --net_inputch 3 \
                                        --net_outputch 2 \
                                        --net_norm batch \
                                        --net_nnblock False \
                                        --net_supervision True \
                                        --lossfn skel_FocalLoss \
                                        --precision 16 \
                                        --data_patchsize 128_128 \
                                        --batch_size 24 \
                                        --lr 1e-3
# Out:
# args: Namespace(batch_size=24, data_cropsize=None, data_dir='DRIVE', data_module='dataset', data_padsize=None, data_patchsize='128_128', data_resize=None, experiment_name=None, lossfn='skel_FocalLoss', lr=0.001, net='waveletunet_att', net_activation='relu', net_ckpt=None, net_inputch=3, net_nnblock=False, net_norm='batch', net_outputch=2, net_supervision=True, precision=16, project='RetinaV3')
#
# project RetinaV3
# Current Experiment: DatasetDRIVE_Netwaveletunet_att_Netnormbatch_Netinputch3_Netoutputch2_Lossskel_FocalLoss_Lr0.001_Precision16_Patchsize128_128_PrefixNone_
#  ****************************************************************************************************
# wandb: Currently logged in as: ps4southwest (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.1
# wandb: Syncing run DatasetDRIVE_Netwaveletunet_att_Netnormbatch_Netinputch3_Netoutputch2_Lossskel_FocalLoss_Lr0.001_Precision16_Patchsize128_128_PrefixNone_
# wandb:  View project at https://wandb.ai/ps4southwest/RetinaV3
# wandb:  View run at https://wandb.ai/ps4southwest/RetinaV3/runs/1mpx35k1
# wandb: Run data is saved locally in logs/wandb/run-20210830_084633-1mpx35k1
# wandb: Run `wandb offline` to turn off syncing.
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# total counts of dataset x 18, y 18
# total counts of dataset x 2, y 2
# total counts of dataset x 20, y 20
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [7]
#
#   | Name   | Type            | Params
# -------------------------------------------
# 0 | lossfn | skel_FocalLoss  | 0
# 1 | net    | waveletunet_att | 27.7 M
# 2 | metric | F1              | 0
# -------------------------------------------
# 27.7 M    Trainable params
# 0         Non-trainable params
# 27.7 M    Total params
# 110.618   Total estimated model params size (MB)
# Epoch 0:  50%|▌| 1/2 [00:05<00:05,  5.66s/it, loss=1.57, v_num=35k1, loss_val=1./home/ps4southwest/.local/lib/python3.8/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
#
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█| 2/2 [00:15<00:00,  7.91s/it, loss=1.570, v_num=35k1, loss_val=1
#                                                                                 Epoch 0, global step 0: metric_val reached 0.08183 (best 0.08183), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0000-loss_val=1.6443-metric_val=0.0818.ckpt" as top 3
# Epoch 1:  50%|▌| 1/2 [00:08<00:08,  8.65s/it, loss=1.570, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 2/2 [00:18<00:00,  9.29s/it, loss=1.590, v_num=35k1, loss_val=1
#                                                                                 Epoch 1, global step 1: metric_val reached 0.08183 (best 0.08183), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0001-loss_val=1.6442-metric_val=0.0818.ckpt" as top 3
# Epoch 2:  50%|▌| 1/2 [00:08<00:08,  8.55s/it, loss=1.590, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 2/2 [00:19<00:00,  9.50s/it, loss=1.560, v_num=35k1, loss_val=1
#                                                                                 Epoch 2, global step 2: metric_val reached 0.08183 (best 0.08183), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0002-loss_val=1.6443-metric_val=0.0818.ckpt" as top 3
# Epoch 3:  50%|▌| 1/2 [00:05<00:05,  5.53s/it, loss=1.560, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 2/2 [00:15<00:00,  7.59s/it, loss=1.620, v_num=35k1, loss_val=1
#                                                                                 Epoch 3, global step 3: metric_val was not in top 3
# Epoch 4:  50%|▌| 1/2 [00:05<00:05,  5.46s/it, loss=1.620, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 2/2 [00:15<00:00,  7.82s/it, loss=1.520, v_num=35k1, loss_val=1
#                                                                                 Epoch 4, global step 4: metric_val reached 0.08732 (best 0.08732), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0004-loss_val=1.6450-metric_val=0.0873.ckpt" as top 3
# Epoch 5:  50%|▌| 1/2 [00:04<00:04,  4.66s/it, loss=1.520, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 2/2 [00:16<00:00,  8.23s/it, loss=1.500, v_num=35k1, loss_val=1
#                                                                                 Epoch 5, global step 5: metric_val reached 0.22367 (best 0.22367), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0005-loss_val=1.6451-metric_val=0.2237.ckpt" as top 3
# Epoch 6:  50%|▌| 1/2 [00:06<00:06,  6.28s/it, loss=1.500, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 2/2 [00:16<00:00,  8.17s/it, loss=1.370, v_num=35k1, loss_val=1
#                                                                                 Epoch 6, global step 6: metric_val reached 0.35766 (best 0.35766), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0006-loss_val=1.6441-metric_val=0.3577.ckpt" as top 3
# Epoch 7:  50%|▌| 1/2 [00:04<00:04,  4.74s/it, loss=1.370, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 2/2 [00:15<00:00,  7.64s/it, loss=1.410, v_num=35k1, loss_val=1
#                                                                                 Epoch 7, global step 7: metric_val reached 0.51105 (best 0.51105), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0007-loss_val=1.6421-metric_val=0.5110.ckpt" as top 3
# Epoch 8:  50%|▌| 1/2 [00:07<00:07,  7.73s/it, loss=1.410, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 2/2 [00:18<00:00,  9.23s/it, loss=1.410, v_num=35k1, loss_val=1
#                                                                                 Epoch 8, global step 8: metric_val reached 0.79460 (best 0.79460), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0008-loss_val=1.6387-metric_val=0.7946.ckpt" as top 3
# Epoch 9:  50%|▌| 1/2 [00:08<00:08,  8.52s/it, loss=1.410, v_num=35k1, loss_val=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 2/2 [00:18<00:00,  9.31s/it, loss=1.370, v_num=35k1, loss_val=1
#                                                                                 Epoch 9, global step 9: metric_val reached 0.91444 (best 0.91444), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0009-loss_val=1.6345-metric_val=0.9144.ckpt" as top 3
# Epoch 10:  50%|▌| 1/2 [00:07<00:07,  7.69s/it, loss=1.370, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 2/2 [00:17<00:00,  8.82s/it, loss=1.320, v_num=35k1, loss_val=
#                                                                                 Epoch 10, global step 10: metric_val reached 0.91817 (best 0.91817), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0010-loss_val=1.6296-metric_val=0.9182.ckpt" as top 3
# Epoch 11:  50%|▌| 1/2 [00:06<00:06,  6.12s/it, loss=1.320, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 2/2 [00:15<00:00,  7.95s/it, loss=1.360, v_num=35k1, loss_val=
#                                                                                 Epoch 11, global step 11: metric_val reached 0.91817 (best 0.91817), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0011-loss_val=1.6246-metric_val=0.9182.ckpt" as top 3
# Epoch 12:  50%|▌| 1/2 [00:06<00:06,  6.22s/it, loss=1.360, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 2/2 [00:16<00:00,  8.31s/it, loss=1.400, v_num=35k1, loss_val=
#                                                                                 Epoch 12, global step 12: metric_val reached 0.91817 (best 0.91817), saving model to "logs/RetinaV3/1mpx35k1/checkpoints/epoch=0012-loss_val=1.6188-metric_val=0.9182.ckpt" as top 3
# Epoch 13:  50%|▌| 1/2 [00:04<00:04,  4.59s/it, loss=1.400, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 2/2 [00:14<00:00,  7.26s/it, loss=1.290, v_num=35k1, loss_val=
#                                                                                 Epoch 13, global step 13: metric_val was not in top 3
# Epoch 14:  50%|▌| 1/2 [00:05<00:05,  5.56s/it, loss=1.290, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 2/2 [00:15<00:00,  7.98s/it, loss=1.290, v_num=35k1, loss_val=
#                                                                                 Epoch 14, global step 14: metric_val was not in top 3
# Epoch 15:  50%|▌| 1/2 [00:04<00:04,  4.65s/it, loss=1.290, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 2/2 [00:14<00:00,  7.29s/it, loss=1.320, v_num=35k1, loss_val=
#                                                                                 Epoch 15, global step 15: metric_val was not in top 3
# Epoch 16:  50%|▌| 1/2 [00:06<00:06,  6.38s/it, loss=1.320, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 2/2 [00:17<00:00,  8.84s/it, loss=1.280, v_num=35k1, loss_val=
#                                                                                 Epoch 16, global step 16: metric_val was not in top 3
# Epoch 17:  50%|▌| 1/2 [00:05<00:05,  5.53s/it, loss=1.280, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 2/2 [00:21<00:00, 10.57s/it, loss=1.280, v_num=35k1, loss_val=
#                                                                                 Epoch 17, global step 17: metric_val was not in top 3
# Epoch 18:  50%|▌| 1/2 [00:07<00:07,  7.82s/it, loss=1.280, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 2/2 [00:22<00:00, 11.33s/it, loss=1.210, v_num=35k1, loss_val=
#                                                                                 Epoch 18, global step 18: metric_val was not in top 3
# Epoch 19:  50%|▌| 1/2 [00:07<00:07,  7.47s/it, loss=1.210, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 2/2 [00:23<00:00, 11.59s/it, loss=1.300, v_num=35k1, loss_val=
#                                                                                 Epoch 19, global step 19: metric_val was not in top 3
# Epoch 20:  50%|▌| 1/2 [00:07<00:07,  7.17s/it, loss=1.300, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 2/2 [00:23<00:00, 11.94s/it, loss=1.240, v_num=35k1, loss_val=
#                                                                                 Epoch 20, global step 20: metric_val was not in top 3
# Epoch 21:  50%|▌| 1/2 [00:06<00:06,  6.08s/it, loss=1.240, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 2/2 [00:22<00:00, 11.16s/it, loss=1.160, v_num=35k1, loss_val=
#                                                                                 Epoch 21, global step 21: metric_val was not in top 3
# Epoch 22:  50%|▌| 1/2 [00:05<00:05,  5.65s/it, loss=1.160, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 2/2 [00:20<00:00, 10.25s/it, loss=1.320, v_num=35k1, loss_val=
#                                                                                 Epoch 22, global step 22: metric_val was not in top 3
# Epoch 23:  50%|▌| 1/2 [00:05<00:05,  5.70s/it, loss=1.320, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|█| 2/2 [00:21<00:00, 10.55s/it, loss=1.360, v_num=35k1, loss_val=
#                                                                                 Epoch 23, global step 23: metric_val was not in top 3
# Epoch 24:  50%|▌| 1/2 [00:06<00:06,  6.01s/it, loss=1.360, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|█| 2/2 [00:21<00:00, 10.62s/it, loss=1.080, v_num=35k1, loss_val=
#                                                                                 Epoch 24, global step 24: metric_val was not in top 3
# Epoch 25:  50%|▌| 1/2 [00:08<00:08,  8.65s/it, loss=1.080, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 25: 100%|█| 2/2 [00:24<00:00, 12.29s/it, loss=1.150, v_num=35k1, loss_val=
#                                                                                 Epoch 25, global step 25: metric_val was not in top 3
# Epoch 26:  50%|▌| 1/2 [00:05<00:05,  5.75s/it, loss=1.150, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 26: 100%|█| 2/2 [00:21<00:00, 10.65s/it, loss=1.210, v_num=35k1, loss_val=
#                                                                                 Epoch 26, global step 26: metric_val was not in top 3
# Epoch 27:  50%|▌| 1/2 [00:06<00:06,  6.41s/it, loss=1.210, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 27: 100%|█| 2/2 [00:21<00:00, 10.95s/it, loss=1.090, v_num=35k1, loss_val=
#                                                                                 Epoch 27, global step 27: metric_val was not in top 3
# Epoch 28:  50%|▌| 1/2 [00:05<00:05,  5.83s/it, loss=1.090, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 28: 100%|█| 2/2 [00:20<00:00, 10.14s/it, loss=1.280, v_num=35k1, loss_val=
#                                                                                 Epoch 28, global step 28: metric_val was not in top 3
# Epoch 29:  50%|▌| 1/2 [00:07<00:07,  7.20s/it, loss=1.280, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 29: 100%|█| 2/2 [00:21<00:00, 10.58s/it, loss=1.080, v_num=35k1, loss_val=
#                                                                                 Epoch 29, global step 29: metric_val was not in top 3
# Epoch 30:  50%|▌| 1/2 [00:07<00:07,  7.59s/it, loss=1.080, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 30: 100%|█| 2/2 [00:22<00:00, 11.20s/it, loss=1.140, v_num=35k1, loss_val=
#                                                                                 Epoch 30, global step 30: metric_val was not in top 3
# Epoch 31:  50%|▌| 1/2 [00:07<00:07,  7.48s/it, loss=1.140, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 31: 100%|█| 2/2 [00:22<00:00, 11.23s/it, loss=1.140, v_num=35k1, loss_val=
#                                                                                 Epoch 31, global step 31: metric_val was not in top 3
# Epoch 32:  50%|▌| 1/2 [00:07<00:07,  7.62s/it, loss=1.140, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 32: 100%|█| 2/2 [00:22<00:00, 11.04s/it, loss=1.090, v_num=35k1, loss_val=
#                                                                                 Epoch 32, global step 32: metric_val was not in top 3
# Epoch 33:  50%|▌| 1/2 [00:06<00:06,  6.30s/it, loss=1.090, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 33: 100%|█| 2/2 [00:20<00:00, 10.05s/it, loss=1.200, v_num=35k1, loss_val=
#                                                                                 Epoch 33, global step 33: metric_val was not in top 3
# Epoch 34:  50%|▌| 1/2 [00:05<00:05,  5.85s/it, loss=1.200, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 34: 100%|█| 2/2 [00:17<00:00,  8.53s/it, loss=1.080, v_num=35k1, loss_val=
#                                                                                 Epoch 34, global step 34: metric_val was not in top 3
# Epoch 35:  50%|▌| 1/2 [00:06<00:06,  6.40s/it, loss=1.080, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 35: 100%|█| 2/2 [00:16<00:00,  8.39s/it, loss=1.050, v_num=35k1, loss_val=
#                                                                                 Epoch 35, global step 35: metric_val was not in top 3
# Epoch 36:  50%|▌| 1/2 [00:06<00:06,  6.88s/it, loss=1.050, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 36: 100%|█| 2/2 [00:17<00:00,  8.88s/it, loss=1.050, v_num=35k1, loss_val=
#                                                                                 Epoch 36, global step 36: metric_val was not in top 3
# Epoch 37:  50%|▌| 1/2 [00:07<00:07,  7.86s/it, loss=1.050, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 37: 100%|█| 2/2 [00:18<00:00,  9.41s/it, loss=1.060, v_num=35k1, loss_val=
#                                                                                 Epoch 37, global step 37: metric_val was not in top 3
# Epoch 38:  50%|▌| 1/2 [00:07<00:07,  7.18s/it, loss=1.060, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 38: 100%|█| 2/2 [00:17<00:00,  8.89s/it, loss=1.020, v_num=35k1, loss_val=
#                                                                                 Epoch 38, global step 38: metric_val was not in top 3
# Epoch 39:  50%|▌| 1/2 [00:07<00:07,  7.43s/it, loss=1.020, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 39: 100%|█| 2/2 [00:17<00:00,  8.98s/it, loss=0.958, v_num=35k1, loss_val=
#                                                                                 Epoch 39, global step 39: metric_val was not in top 3
# Epoch 40:  50%|▌| 1/2 [00:09<00:09,  9.33s/it, loss=0.958, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 40: 100%|█| 2/2 [00:19<00:00,  9.89s/it, loss=1.060, v_num=35k1, loss_val=
#                                                                                 Epoch 40, global step 40: metric_val was not in top 3
# Epoch 41:  50%|▌| 1/2 [00:08<00:08,  8.06s/it, loss=1.060, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 41: 100%|█| 2/2 [00:18<00:00,  9.06s/it, loss=0.970, v_num=35k1, loss_val=
#                                                                                 Epoch 41, global step 41: metric_val was not in top 3
# Epoch 42:  50%|▌| 1/2 [00:05<00:05,  5.54s/it, loss=0.970, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 42: 100%|█| 2/2 [00:15<00:00,  7.75s/it, loss=0.987, v_num=35k1, loss_val=
#                                                                                 Epoch 42, global step 42: metric_val was not in top 3
# Epoch 43:  50%|▌| 1/2 [00:06<00:06,  6.25s/it, loss=0.987, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 43: 100%|█| 2/2 [00:16<00:00,  8.25s/it, loss=1.010, v_num=35k1, loss_val=
#                                                                                 Epoch 43, global step 43: metric_val was not in top 3
# Epoch 44:  50%|▌| 1/2 [00:06<00:06,  6.07s/it, loss=1.010, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 44: 100%|█| 2/2 [00:15<00:00,  8.00s/it, loss=1.050, v_num=35k1, loss_val=
#                                                                                 Epoch 44, global step 44: metric_val was not in top 3
# Epoch 45:  50%|▌| 1/2 [00:06<00:06,  6.16s/it, loss=1.050, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 45: 100%|█| 2/2 [00:15<00:00,  7.94s/it, loss=1.000, v_num=35k1, loss_val=
#                                                                                 Epoch 45, global step 45: metric_val was not in top 3
# Epoch 46:  50%|▌| 1/2 [00:04<00:04,  4.57s/it, loss=1.000, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 46: 100%|█| 2/2 [00:14<00:00,  7.22s/it, loss=0.947, v_num=35k1, loss_val=
#                                                                                 Epoch 46, global step 46: metric_val was not in top 3
# Epoch 47:  50%|▌| 1/2 [00:06<00:06,  6.20s/it, loss=0.947, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 47: 100%|█| 2/2 [00:17<00:00,  8.53s/it, loss=1.020, v_num=35k1, loss_val=
#                                                                                 Epoch 47, global step 47: metric_val was not in top 3
# Epoch 48:  50%|▌| 1/2 [00:06<00:06,  6.92s/it, loss=1.020, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 48: 100%|█| 2/2 [00:17<00:00,  8.62s/it, loss=1.110, v_num=35k1, loss_val=
#                                                                                 Epoch 48, global step 48: metric_val was not in top 3
# Epoch 49:  50%|▌| 1/2 [00:07<00:07,  7.64s/it, loss=1.110, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█| 2/2 [00:18<00:00,  9.15s/it, loss=0.968, v_num=35k1, loss_val=
#                                                                                 Epoch 49, global step 49: metric_val was not in top 3
# Epoch 50:  50%|▌| 1/2 [00:05<00:05,  5.87s/it, loss=0.968, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 50: 100%|█| 2/2 [00:16<00:00,  8.44s/it, loss=1.020, v_num=35k1, loss_val=
#                                                                                 Epoch 50, global step 50: metric_val was not in top 3
# Epoch 51:  50%|▌| 1/2 [00:06<00:06,  6.46s/it, loss=1.020, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 51: 100%|█| 2/2 [00:16<00:00,  8.38s/it, loss=0.913, v_num=35k1, loss_val=
#                                                                                 Epoch 51, global step 51: metric_val was not in top 3
# Epoch 52:  50%|▌| 1/2 [00:05<00:05,  5.53s/it, loss=0.913, v_num=35k1, loss_val=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]

# %%
# !free -m

# %%
# !CUDA_VISIBLE_DEVICES=6 python3 -m wandb agent ps4southwest/RetinaV3/5rfecodw

# %% [markdown]
# # Sweeps

# %%
# generate sweep using sweep.yaml
# !python -m wandb sweep sweep.yaml

# %%
# Run sweeps
# !CUDA_VISIBLE_DEVICES=0 python -m wandb agent [your_sweep_address]
# !CUDA_VISIBLE_DEVICES=6 python -m wandb agent keewonshin/Retina/yy8sgak3
